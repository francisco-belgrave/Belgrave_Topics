# %% [markdown]
# <img src="https://user-images.strikinglycdn.com/res/hrscywv4p/image/upload/c_limit,fl_lossy,h_300,w_300,f_auto,q_auto/1266110/Logo_wzxi0f.png" style="float: left; margin: 20px; height: 55px">
#
# ***Peace can only come as a natural consequence of universal enlightenment and merging of races, an we are still far from this blissful realization - [Nikola Tesla](https://en.wikipedia.org/wiki/Nikola_Tesla)***

# %% [markdown]
# # 1. Matplotlib

# %%
# %matplotlib inline

# %% [markdown]
# Why we have to use [`%matplotlib inline`](https://stackoverflow.com/questions/43027980/purpose-of-matplotlib-inline)?

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ### Line Charts

# %% [markdown]
# We will use this [csv](Resources/unrate.csv)

# %%
unrate = pd.read_csv('Resources/unrate.csv')
unrate.DATE = pd.to_datetime(unrate.DATE)
unrate.head(12)
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5
# 5  1948-06-01    3.6
# 6  1948-07-01    3.6
# 7  1948-08-01    3.9
# 8  1948-09-01    3.8
# 9  1948-10-01    3.7
# 10 1948-11-01    3.8
# 11 1948-12-01    4.0

# %% [markdown]
# You can do `shift` + `tab` inside the brackets of a function to access more information about it.

# %%
plt.plot(unrate.DATE.head(12), unrate.VALUE.head(12), 'r*-')
plt.xticks(rotation = 90)
plt.xlabel('Month')
plt.ylabel('Unemployment Rate')
plt.title('Monthly Unemployment Trends, 1948')
plt.show()

# %%
fig = plt.figure(figsize = (14, 20))
plt.title('Monthly Unemployment Trends, 1948-1952')

ax1 = fig.add_subplot(5,1,1)
ax2 = fig.add_subplot(5,1,2)
ax3 = fig.add_subplot(5,1,3)
ax4 = fig.add_subplot(5,1,4)
ax5 = fig.add_subplot(5,1,5)

ax1.plot(unrate.DATE.head(12), unrate.VALUE.head(12),'*-')
# ax1.set_title('Monthly Unemployment Rate, 1948')

ax2.plot(unrate.DATE[12:24],unrate.VALUE[12:24],'r*-')
# ax2.set_title('Monthly Unemployment Rate, 1949')

ax3.plot(unrate.DATE[24:36],unrate.VALUE[24:36],'y*-')
# ax3.set_title('Monthly Unemployment Rate, 1950')

ax4.plot(unrate.DATE[36:48],unrate.VALUE[36:48],'g*-')
# ax4.set_title('Monthly Unemployment Rate, 1951')

ax5.plot(unrate.DATE[48:60],unrate.VALUE[48:60],'m*-')
# ax5.set_title('Monthly Unemployment Rate, 1952')

plt.show()

# %% [markdown]
# Using functions rather than methods of axis and figures

# %%
plt.figure(figsize = (14, 20))

plt.subplot(5, 1, 1)
plt.plot(unrate.DATE.head(12), unrate.VALUE.head(12),'*-')
plt.title('Monthly Unemployment Rate, 1948')

plt.subplot(5, 1, 2)
plt.plot(unrate.DATE[12:24], unrate.VALUE[12:24],'r*-')
plt.title('Monthly Unemployment Rate, 1949')

plt.subplot(5, 1, 3)
plt.plot(unrate.DATE[24:36], unrate.VALUE[24:36],'y*-')
plt.title('Monthly Unemployment Rate, 1950')

plt.subplot(5, 1, 4)
plt.plot(unrate.DATE[36:48], unrate.VALUE[36:48],'g*-')
plt.title('Monthly Unemployment Rate, 1951')

plt.subplot(5, 1, 5)
plt.plot(unrate.DATE[48:60], unrate.VALUE[48:60],'m*-')
plt.title('Monthly Unemployment Rate, 1952')

plt.show()

# %%
unrate['MONTH'] = unrate['DATE'].dt.month

plt.figure(figsize = (6, 3))

plt.title('Monthly Unemployment Rate, 1948-1949')

plt.plot(unrate.MONTH.head(12), unrate.VALUE.head(12),'r')
plt.plot(unrate.MONTH[12:24], unrate.VALUE[12:24],'b')

plt.xlabel('Month')
plt.ylabel('Unemployment Rate')

plt.show()

# %%
plt.figure(figsize = (10, 6))

plt.title('Monthly Unemployment Trends, 1948-1952')

plt.plot(unrate.MONTH.head(12),unrate.VALUE.head(12),'r')
plt.plot(unrate.MONTH[12:24],unrate.VALUE[12:24],'b')
plt.plot(unrate.MONTH[24:36],unrate.VALUE[24:36],'g')
plt.plot(unrate.MONTH[36:48],unrate.VALUE[36:48],'orange')
plt.plot(unrate.MONTH[48:60],unrate.VALUE[48:60],'k')

plt.xlabel('Month, Integer')
plt.ylabel('Unemployment Rate, Percent')

plt.legend(('1948','1949','1950','1951','1952'), loc ='upper left')

plt.show()

# %%
plt.figure(figsize = (10, 6))

plt.title('Monthly Unemployment Trends, 1948-1952')

plt.plot(unrate.MONTH.head(12),unrate.VALUE.head(12),'r', label='1948')
plt.plot(unrate.MONTH[12:24],unrate.VALUE[12:24],'b', label='1949')
plt.plot(unrate.MONTH[24:36],unrate.VALUE[24:36],'g', label='1950')
plt.plot(unrate.MONTH[36:48],unrate.VALUE[36:48],'orange', label='1951')
plt.plot(unrate.MONTH[48:60],unrate.VALUE[48:60],'k', label='1952')

plt.xlabel('Month, Integer')
plt.ylabel('Unemployment Rate, Percent')

plt.legend(loc ='upper left', bbox_to_anchor=(0.16, 1.15), ncol=5) 

plt.show()

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# For this section we will use a movies rating [csv](Resources/fandango_scores.csv)

# %%
reviews = pd.read_csv('Resources/fandango_scores.csv')

norm_reviews = (reviews.loc[:,['FILM','RT_user_norm',
                'Metacritic_user_nom','IMDB_norm',
                'Fandango_Ratingvalue','Fandango_Stars']]
               )
norm_reviews.head(5)
# Out:
#                              FILM  RT_user_norm  Metacritic_user_nom  \
# 0  Avengers: Age of Ultron (2015)           4.3                 3.55
# 1               Cinderella (2015)           4.0                 3.75
# 2                  Ant-Man (2015)           4.5                 4.05
# 3          Do You Believe? (2015)           4.2                 2.35
# 4   Hot Tub Time Machine 2 (2015)           1.4                 1.70
#
#    IMDB_norm  Fandango_Ratingvalue  Fandango_Stars
# 0       3.90                   4.5             5.0
# 1       3.55                   4.5             5.0
# 2       3.90                   4.5             5.0
# 3       2.70                   4.5             5.0
# 4       2.55                   3.0             3.5

# %%
plt.figure(figsize=(14, 8))

plt.scatter(norm_reviews.Fandango_Ratingvalue, 
            norm_reviews.RT_user_norm, 
            c = 'g', 
            alpha = 1,
            marker=r'$\clubsuit$')
plt.show()

# %%
plt.figure(figsize=(14, 18))

plt.subplot(3,1,1)
plt.scatter(norm_reviews.Fandango_Ratingvalue, 
            norm_reviews.RT_user_norm, 
            c = 'g',
            alpha = 1,
            marker = '_')
plt.xlabel('Fandango', fontsize=20)
plt.ylabel('Rotten Tomatoes', fontsize=20)
plt.xlim(2.5, 5)
plt.ylim(0, 5)

plt.subplot(3,1,2)
plt.scatter(norm_reviews.Fandango_Ratingvalue, 
            norm_reviews.Metacritic_user_nom,
            c = 'r',
            alpha = 1, 
            marker = 'D')
plt.xlabel('Fandango', fontsize=20)
plt.ylabel('Metacritic', fontsize=20)
plt.xlim(2.5, 5)
plt.ylim(0, 5)

plt.subplot(3,1,3)
plt.scatter(norm_reviews.Fandango_Ratingvalue, 
            norm_reviews.IMDB_norm,
            c = 'b',
            alpha = 1,
            marker = '|')
plt.xlabel('Fandango', fontsize=20)
plt.ylabel('IMDB', fontsize=20)
plt.xlim(2.5, 5)
plt.ylim(0, 5)

plt.show()

# %% [markdown]
# ### Bar Plots

# %% [markdown]
# #### Vertical

# %%
num_cols = ['RT_user_norm', 'Metacritic_user_nom',
             'IMDB_norm', 'Fandango_Ratingvalue',
             'Fandango_Stars']

bar_heights = norm_reviews[num_cols].iloc[0].values
bar_positions = np.arange(5) + 1

plt.figure(figsize=(14, 12))

plt.bar(bar_positions, bar_heights, 0.5) 

plt.xticks(bar_positions, num_cols, rotation = 90)

plt.xlabel('Rating Source')
plt.ylabel('Average Rating')
plt.title('Average User Rating for Avengers: Age of Ultron (2015)')

plt.show()

# %%
num_cols = (['RT_user_norm', 'Metacritic_user_nom',
             'IMDB_norm', 'Fandango_Ratingvalue',
             'Fandango_Stars'])

bar_heights = norm_reviews[num_cols].iloc[0].values
bar_positions = range(1, 6)

fig, ax = plt.subplots()

ax.bar(bar_positions, bar_heights, 0.5) 

tick_positions = range(1, 6)
ax.set_xticks(tick_positions)
ax.set_xticklabels(num_cols, rotation = 90)

plt.xlabel('Rating Source')
plt.ylabel('Average Rating')
plt.title('Average User Rating for Avengers: Age of Ultron (2015)')

plt.show()

# %% [markdown]
# #### Horizontal

# %%
num_cols = (['RT_user_norm', 'Metacritic_user_nom',
             'IMDB_norm', 'Fandango_Ratingvalue',
             'Fandango_Stars'])

bar_widths = norm_reviews[num_cols].iloc[0].values
bar_positions = np.arange(5) + 1

plt.figure(figsize=(14, 12))

plt.barh(bar_positions, bar_widths, 0.5) 

tick_positions = range(1, 6)
plt.yticks(tick_positions, num_cols)

plt.ylabel('Rating Source')
plt.xlabel('Average Rating')
plt.title('Average User Rating for Avengers: Age of Ultron (2015)')

plt.show()

# %%
figh, axh = plt.subplots()

bar_widths = norm_reviews[num_cols].iloc[0].values
bar_positionsh = np.arange(5) + 1

axh.barh(bar_positionsh, bar_widths, 0.5)

tick_positionsh = range(1,6)
axh.set_yticks(tick_positionsh)
axh.set_yticklabels(num_cols)

plt.ylabel('Rating Source')
plt.xlabel('Average Rating')
plt.title('Average User Rating for Avengers: Age of Ultron (2015)')

plt.show()

# %% [markdown]
# ### Histograms

# %%
plt.figure(figsize=(14, 8))

plt.hist(reviews['Fandango_Ratingvalue'])
plt.xlabel('Stars', fontsize=15)
plt.ylabel('Frequence', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(14, 8))

plt.hist(reviews['Fandango_Ratingvalue'], range=(0, 5), bins=20) 
plt.xlabel('Stars', fontsize=15)
plt.ylabel('Frequence', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(16, 20), facecolor='grey', edgecolor='red')

plt.subplot(4,1,1)
plt.hist(reviews['Fandango_Ratingvalue']
          , range = (0, 5)
          , bins = 20)
plt.title('Distribution of Fandango Ratings')
plt.ylim(0, 50)
plt.ylabel('Frequence', fontsize=15)

plt.subplot(4,1,2)
plt.hist(reviews['RT_user_norm']
          , range = (0, 5)
          , bins = 20)
plt.title('Distribution of Rotten Tomatoes Ratings')
plt.ylim(0, 50)
plt.ylabel('Frequence', fontsize=15)

plt.subplot(4,1,3)
plt.hist(reviews['Metacritic_user_nom']
          , range = (0, 5)
          , bins = 20)
plt.title('Distribution of Metacritic Ratings')
plt.ylim(0, 50)
plt.ylabel('Frequence', fontsize=15)

plt.subplot(4,1,4)
plt.hist(reviews['IMDB_norm']
          , range = (0, 5)
          , bins = 20)
plt.title('Distribution of IMDB Ratings')
plt.ylim(0, 50)
plt.xlabel('Stars', fontsize=15)
plt.ylabel('Frequence', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(14, 8)) 


plt.hist(reviews['Fandango_Ratingvalue']
          , range = (0, 5)
          , bins = 20
          , label = 'Fandango')

plt.hist(reviews['RT_user_norm']
          , range = (0, 5)
          , bins = 20
          , label = 'Rotten Tomatoes')

plt.hist(reviews['Metacritic_user_nom']
          , range = (0, 5)
          , bins = 20
          , label = 'Metacritic')

plt.hist(reviews['IMDB_norm']
          , range = (0, 5)
          , bins = 20
          , label = 'IMDB')

plt.title('All distributions together')
plt.ylim(0, 50)
plt.xlabel('Stars', fontsize=15)
plt.ylabel('Frequence', fontsize=15)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(14, 8)) 


plt.hist(reviews['Fandango_Ratingvalue']
          , range = (0, 5)
          , bins = 20
          , label = 'Fandango'
          , alpha = 0.4)

plt.hist(reviews['RT_user_norm']
          , range = (0, 5)
          , bins = 20
          , label = 'Rotten Tomatoes'
          , alpha = 0.4)

plt.hist(reviews['Metacritic_user_nom']
          , range = (0, 5)
          , bins = 20
          , label = 'Metacritic'
          , alpha = 0.4)

plt.hist(reviews['IMDB_norm']
          , range = (0, 5)
          , bins = 20
          , label = 'IMDB'
          , alpha = 0.4)

plt.title('All distributions together')
plt.ylim(0, 50)
plt.xlabel('Stars', fontsize=15)
plt.ylabel('Frequence', fontsize=15)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(14, 8)) 


plt.hist(reviews['Fandango_Ratingvalue']
          , range = (0, 5)
          , bins = 20
          , label = 'Fandango'
          , alpha = 0.5)

plt.hist(reviews['IMDB_norm']
          , range = (0, 5)
          , bins = 20
          , label = 'IMDB'
          , alpha = 0.5)

plt.title('Fandango and IMDB distributions together')
plt.ylim(0, 50)
plt.xlabel('Stars', fontsize=15)
plt.ylabel('Frequence', fontsize=15)
plt.legend()

plt.show()

# %%
fandango_distribution = plt.hist(reviews['Fandango_Ratingvalue'], bins=np.linspace(2, 5, 15))

imdb_distribution = plt.hist(reviews['IMDB_norm'], bins=np.linspace(2, 5, 15))

# %%
fandango_distribution
# Out:
# (array([ 0.,  0.,  0.,  4.,  9.,  8., 13., 26., 17., 23., 23., 16.,  4.,
#          3.]),
#  array([2.        , 2.21428571, 2.42857143, 2.64285714, 2.85714286,
#         3.07142857, 3.28571429, 3.5       , 3.71428571, 3.92857143,
#         4.14285714, 4.35714286, 4.57142857, 4.78571429, 5.        ]),
#  <a list of 14 Patch objects>)

# %%
imdb_distribution
# Out:
# (array([ 4.,  2.,  6., 12., 10., 20., 24., 34., 22.,  8.,  4.,  0.,  0.,
#          0.]),
#  array([2.        , 2.21428571, 2.42857143, 2.64285714, 2.85714286,
#         3.07142857, 3.28571429, 3.5       , 3.71428571, 3.92857143,
#         4.14285714, 4.35714286, 4.57142857, 4.78571429, 5.        ]),
#  <a list of 14 Patch objects>)

# %%
plt.figure(figsize=(16, 12))

plt.bar(fandango_distribution[1][:-1], fandango_distribution[0], 
        width=0.075, 
        align='edge', 
        label='Fandango', 
        color='red') 

plt.bar(imdb_distribution[1][:-1], imdb_distribution[0], 
        width=-0.075, 
        align='edge', 
        label='IMDB', 
        color='yellow') 

plt.xlabel('Stars', fontsize=15)
plt.ylabel('Frequence', fontsize=15)
plt.title('Fandango and IMDB ratings')
plt.legend()

plt.show()

# %% [markdown]
# ### Box  Plots

# %% [markdown]
# Full explanation of [box plots](https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51).

# %%
plt.figure(figsize=(14, 8))

plt.boxplot(reviews['RT_user_norm'])
plt.ylim(0, 5)
plt.xticks([1], ['Rotten Tomatoes'], fontsize=15)

# plt.arrow(1.13, 4.7, -0.05, 0, head_length = 0.025, head_width = 0.07) # Less flexible way
plt.annotate(s='', xy=(1.10, 4.7), xytext=(1.05, 4.7), arrowprops=dict(arrowstyle='<-'), fontsize=20)
plt.text(1.1, 4.665, 'Maximum')

plt.annotate(s='', xy=(1.10, 1), xytext=(1.05, 1), arrowprops=dict(arrowstyle='<-'), fontsize=20)
plt.text(1.1, 0.965, 'Minimum')

plt.annotate(s='', xy=(1.13, 3.325), xytext=(1.08, 3.325), arrowprops=dict(arrowstyle='<-'), fontsize=20)
plt.text(1.13, 3.305, 'Median')

plt.annotate(s='', xy=(1.13, 4.05), xytext=(1.08, 4.05), arrowprops=dict(arrowstyle='<-'), fontsize=20)
plt.text(1.13, 4.02, '75th Percentile')

plt.annotate(s='', xy=(1.13, 2.5), xytext=(1.08, 2.5), arrowprops=dict(arrowstyle='<-'), fontsize=20)
plt.text(1.13, 2.452, '25th Percentile')

plt.show()

# %%
num_cols = ['RT_user_norm', 'Metacritic_user_nom',
             'IMDB_norm', 'Fandango_Ratingvalue',
             'Fandango_Stars']

plt.figure(figsize=(16, 8))

plt.boxplot(norm_reviews[num_cols].values)
plt.xticks( range(1, 6), num_cols, rotation = 45, fontsize=15)
plt.ylim(0, 5)

plt.annotate(s='', xy=(2.2, 1.2), xytext=(2.02, 1.2), arrowprops=dict(arrowstyle='<-'), fontsize=20, color='k')
plt.text(2.21, 1.180, 'Outliers')

plt.show()

# %% [markdown]
# ### Improving Plot Aesthetics

# %% [markdown]
# If you don't have time you can use [style sheets](https://matplotlib.org/users/style_sheets.html). We are going to use a [dataset](Resources/percent-bachelors-degrees-women-usa.csv) of the percentage of women studying several degrees.

# %%
women_degrees = pd.read_csv('Resources/percent-bachelors-degrees-women-usa.csv')
women_degrees.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
plt.figure(figsize=(16, 10))

plt.plot(women_degrees['Year'], women_degrees['Biology'],
        label ='Women', color = 'b')

plt.plot(women_degrees['Year'], 100 - women_degrees['Biology'],
        label ='Men', color = 'g')

plt.legend(loc ='upper right')
plt.xlabel('Year')
plt.ylabel('%')
plt.title('Percentage of Biology Degrees Awarded By Gender')

plt.show()

# %%
plt.figure(figsize=(16, 10))

plt.plot(women_degrees['Year'], women_degrees['Biology'],
        label ='Women', color = 'b')

plt.plot(women_degrees['Year'], 100 - women_degrees['Biology'],
        label ='Men', color = 'g')

plt.legend(loc ='upper right')
plt.xlabel('Year')
plt.ylabel('%')
plt.grid(True)
plt.title('Percentage of Biology Degrees Awarded By Gender')

plt.show()

# %%
fig1 = plt.figure(figsize=(16, 10))
ax1 = fig1.add_subplot(1,1,1)

plt.plot(women_degrees['Year'], women_degrees['Biology'],
        label ='Women', color = 'b')

plt.plot(women_degrees['Year'], 100 - women_degrees['Biology'],
        label ='Men', color = 'g')

plt.legend(loc ='upper right')
plt.xlabel('Year')
plt.ylabel('%')
plt.title('Percentage of Biology Degrees Awarded By Gender')

ax1.tick_params(bottom=False, top=False,
                 left=False, right=False)

plt.show()

# %%
fig2 = plt.figure(figsize=(16, 10))
ax2 = fig2.add_subplot(1,1,1)

plt.plot(women_degrees['Year'], women_degrees['Biology'],
        label ='Women', color = 'b')

plt.plot(women_degrees['Year'], 100 - women_degrees['Biology'],
        label ='Men', color = 'g')

plt.legend(loc ='upper right')
plt.xlabel('Year')
plt.ylabel('%')

plt.title('Percentage of Biology Degrees Awarded By Gender')

ax2.axhline(50, linestyle='-', color='k', alpha=0.15) # You can also use plt.hlines()

ax2.tick_params(bottom=False, top=False,
                 left=False, right=False)

ax2.spines["right"].set_visible(False)
ax2.spines["left"].set_visible(False)
ax2.spines["top"].set_visible(False)
ax2.spines["bottom"].set_visible(False)

plt.show()

# %%
major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']

fig3 = plt.figure(figsize=(20, 12))

for sp in range(0, 4):
    
    ax = fig3.add_subplot(2,2, sp+1)
    
    ax.plot(women_degrees['Year'], women_degrees[major_cats[sp]], c='blue', label='Women')
    ax.plot(women_degrees['Year'], 100 - women_degrees[major_cats[sp]], c='green', label='Men')
    
    plt.xlim(1968, 2011)
    plt.ylim(0, 100)
    
    plt.xlabel('Year')
    plt.ylabel('%')
    plt.title(f'{major_cats[sp]}') 
    plt.legend(loc='upper center')
    
    ax.axhline(50, linestyle='--', color='k', alpha=0.15) # You can also use plt.hlines()
    
    ax.tick_params(bottom =False, top =False,
                 left =False, right =False)

    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)
    ax.spines["bottom"].set_visible(False)

plt.show()

# %%
stem_cats = ['Engineering', 'Computer Science',
             'Psychology', 'Biology',
             'Physical Sciences', 'Math and Statistics']

cb_dark_blue = (0/255, 107/255, 164/255)
cb_orange = (255/255, 128/255, 14/255)

fig3 = plt.figure(figsize = (20, 4))
end = 6

for sp in range(0, end):
    ax = fig3.add_subplot(1,6,sp+1)
    
    if sp == 0:
        ax.text(2005, 87,"Men")
        ax.text(2002, 8,"Women")
    
    if sp == end - 1:
        ax.text(2005, 62,"Men")
        ax.text(2001, 35,"Women")
        
    ax.plot(women_degrees['Year'],
            women_degrees[stem_cats[sp]],
            c = cb_dark_blue, 
            label='Women',
            linewidth=4)
    
    ax.plot(women_degrees['Year'],
            100-women_degrees[stem_cats[sp]],
            c=cb_orange, 
            label='Men', 
            linewidth=4)
    
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    if sp > 0:
        ax.get_yaxis().set_visible(False)
        
    ax.axhline(50, linestyle='--', color='k', alpha=0.12)        
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)

plt.show()

# %%
lib_arts_cats = ['Foreign Languages', 'English',
                 'Communications and Journalism',
                 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions',
              'Public Administration',
              'Education','Agriculture','Business',
              'Architecture']

fig2 = plt.figure(figsize = (16, 20))

# First column: STEM degrees.

for sp in range(0,18,3):
    cat_index = int(sp/3)
    
    ax = fig2.add_subplot(6, 3, sp+1)
    
    ax.plot(women_degrees['Year'],
            women_degrees[stem_cats[cat_index]],
            c = cb_dark_blue, label ='Women',
            linewidth = 3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[stem_cats[cat_index]],
            c = cb_orange, label ='Men', linewidth = 3)
    
    for key,spine in ax.spines.items():
        spine.set_visible(False)
        
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    ax.set_yticks([0,100])
    ax.axhline(50, c = (171/255, 171/255, 171/255), 
               alpha = 0.5)  
    ax.tick_params(bottom = False, top = False ,
                   left = False, right = False,
                   labelbottom = False)
    
    if cat_index == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif cat_index == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom = True)
       
# Second column: Liberal Arts degrees.

for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    
    ax = fig2.add_subplot(6,3,sp+1)
    
    ax.plot(women_degrees['Year'],
            women_degrees[lib_arts_cats[cat_index]],
            c = cb_dark_blue, label ='Women',
            linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[lib_arts_cats[cat_index]],
            c = cb_orange, label ='Men', linewidth = 3)
    
    for key,spine in ax.spines.items():
        spine.set_visible(False)
        
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    ax.set_yticks([0,100])
    ax.axhline(50, c = (171/255, 171/255, 171/255),
               alpha = 0.5)
    ax.tick_params(bottom = False, top = False ,
                   left = False, right = False,
                   labelbottom = False)
    
    if cat_index == 0:
        ax.text(2003, 78, 'Women')
        ax.text(2005, 18, 'Men')
    elif cat_index == 4:
        ax.tick_params(labelbottom = True)

# Third column: Other degrees.

for sp in range(2,20,3):
    cat_index = int((sp-2)/3)
    
    ax = fig2.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],
            women_degrees[other_cats[cat_index]],
            c = cb_dark_blue, label ='Women', 
            linewidth = 3)
    ax.plot(women_degrees['Year'], 
            100-women_degrees[other_cats[cat_index]],
            c = cb_orange, label ='Men', linewidth = 3)
    
    for key,spine in ax.spines.items():
        spine.set_visible(False)
        
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    ax.set_yticks([0,100])
    ax.axhline(50, c = (171/255, 171/255, 171/255),
               alpha = 0.5)
    ax.tick_params(bottom = False, top = False ,
                   left = False, right = False,
                   labelbottom = False)
    
    if cat_index == 0:
        ax.text(2003, 90, 'Women')
        ax.text(2005, 5, 'Men')
    elif cat_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 30, 'Women')
        ax.tick_params(labelbottom = True)

plt.savefig("gender_degrees.png")
plt.show()

# %% [markdown]
# # 2. Seaborn

# %% [markdown]
# Info from this [article](https://towardsdatascience.com/3-awesome-visualization-techniques-for-every-dataset-9737eecacbe8)

# %%
import seaborn as sns

# %%
# We dont Probably need the Gridlines. Do we? If yes comment this line
sns.set(style="ticks")

flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
flatui = sns.color_palette(flatui)

# %% [markdown]
# In this case, we will use a fifa [dataset](Resources/fifa.csv)

# %%
player_df = pd.read_csv("Resources/fifa.csv")

# %% [markdown]
# ###### Processing

# %%
def wage_split(x):
    try:
        return int(x.split("K")[0][1:])
    except:
        return 0
player_df['Wage'] = player_df['Wage'].apply(lambda x : wage_split(x))

def value_split(x):
    try:
        if 'M' in x:
            return float(x.split("M")[0][1:])
        elif 'K' in x:
            return float(x.split("K")[0][1:])/1000
    except:
        return 0
    
player_df['Value'] = player_df['Value'].apply(lambda x : value_split(x))

# %%
numcols = [
 'Overall',
 'Potential',
'Crossing','Finishing',  'ShortPassing',  'Dribbling','LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility',  'Stamina',
 'Value','Wage']
catcols = ['Name','Club','Nationality','Preferred Foot','Position','Body Type']

# %%
player_df = player_df[numcols+catcols]

# %%
filtered_player_df = player_df[(player_df['Club'].isin(['FC Barcelona', 'Paris Saint-Germain',
       'Manchester United', 'Manchester City', 'Chelsea', 'Real Madrid','FC Porto','FC Bayern München'])) & 
                      (player_df['Nationality'].isin(['England', 'Brazil', 'Argentina',
       'Brazil', 'Italy','Spain','Germany'])) 
                     ]

df_plot = filtered_player_df.groupby(['Club', 'Nationality']).size().reset_index().pivot(columns='Club', index='Nationality', values=0).reset_index()

# %%
max_wage = filtered_player_df.Wage.max()
max_wage_player = filtered_player_df[(player_df['Wage'] == max_wage)]['Name'].values[0]
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df1 = df_plot.set_index('Nationality').T

# %% [markdown]
# ### Correlation Plot

# %%
corr = player_df.corr()

g = sns.heatmap(corr, annot=True, annot_kws={"size":15})

plt.autoscale()

g.figure.set_size_inches(20,14)

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.show()

# %% [markdown]
# ### Pairplots

# %%
sns.pairplot(filtered_player_df[['Value','SprintSpeed','Potential','Wage']])
plt.show()

# %%
sns.pairplot(filtered_player_df[['Value','SprintSpeed','Potential','Wage','Club']], hue = 'Club')
plt.show()

# %% [markdown]
# ### Swarmplots

# %%
plt.figure(figsize=(20,14))

sns.swarmplot(y = "Club",
              x = 'Wage', 
              data = filtered_player_df,
              # Decrease the size of the points to avoid crowding 
              size = 7)

# remove the top and right line in graph
sns.despine()

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Wage', fontsize=18)
plt.ylabel('Club', fontsize=18)

plt.show()

# %%
sns.boxplot(y = "Club",
              x = 'Wage', 
              data = filtered_player_df,
              whis=np.inf)

g = sns.swarmplot(y = "Club",
              x = 'Wage', 
              data = filtered_player_df,
              # Decrease the size of the points to avoid crowding 
              size = 7,
              color='black')

# remove the top and right line in graph
sns.despine()

# Annotate. xy for coordinate. max_wage is x and 0 is y. In this plot y ranges from 0 to 7 for each level
# xytext for coordinates of where I want to put my text
plt.annotate(s = max_wage_player,
             xy = (max_wage,0),
             xytext = (500,1), 
             # Shrink the arrow to avoid occlusion
             arrowprops = {'facecolor':'gray', 'width': 3, 'shrink': 0.03},
             backgroundcolor = 'white')
g.figure.set_size_inches(12,8)

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Club', fontsize=18)
plt.ylabel('Wage', fontsize=18)

plt.show()

# %% [markdown]
# ### Grid

# %% [markdown]
# Titanic [dataset](Resources/train_titanic.csv)

# %%
titanic = pd.read_csv('Resources/train_titanic.csv')

# %%
g = sns.FacetGrid(titanic, 
                  col ="Survived",
                  row ="Pclass",
                  hue ='Sex', 
                  height = 2.9)

g.map(sns.kdeplot, "Age", shade = True).add_legend()

sns.despine()

plt.show()
