# %% [markdown]
# <img src="https://user-images.strikinglycdn.com/res/hrscywv4p/image/upload/c_limit,fl_lossy,h_300,w_300,f_auto,q_auto/1266110/Logo_wzxi0f.png" style="float: left; margin: 20px; height: 55px">
#
# **If you don’t know how to do something, say yes and learn how to do it later - [Richard Branson](https://en.wikipedia.org/wiki/Richard_Branson)**

# %% [markdown]
# # 1. Introduction to Python Conditional Statements

# %% [markdown]
# In this lecture we will be doing a quick overview of Python Statements. This lecture will emphasize differences between Python and other languages such as C++.
#
# There are two reasons we take this approach for learning the context of Python Statements:
#
#     1.) If you are coming from a different language this will rapidly accelerate your understanding of Python.
#     2.) Learning about statements will allow you to be able to read other languages more easily in the future.

# %% [markdown]
# ## Python vs Other Languages

# %% [markdown]
# Let's create a simple statement that says:
# "If a is greater than b, assign 2 to a and 4 to b"
#
# Take a look at these two if statements (we will learn about building out if statements soon).
#
# **Version 1 (Other Languages)**
#
#     if (a>b){
#         a = 2;
#         b = 4;
#     }
#
# **Version 2 (Python)**
#
#     if a>b:
#         a = 2
#         b = 4

# %% [markdown]
# You'll notice that Python is less cluttered and much more readable than the first version. How does Python manage this?
#
# Let's walk through the main differences:
#
# Python gets rid of () and {} by incorporating two main factors: a *colon* and *whitespace*. The statement is ended with a colon, and whitespace is used (indentation) to describe what takes place in case of the statement.
#
# Another major difference is the lack of semicolons in Python. Semicolons are used to denote statement endings in many other languages, but in Python, the end of a line is the same as the end of a statement.
#
# Lastly, to end this brief overview of differences, let's take a closer look at indentation syntax in Python vs other languages:

# %% [markdown]
# **Indentation**
#
# Here is some pseudo-code to indicate the use of whitespace and indentation in Python:
#
# **Other Languages**
#
#     if (x)
#         if(y)
#             code-statement;
#     else
#         another-code-statement;
#
# **Python**
#
#     if x:
#         if y:
#             code-statement
#     else:
#         another-code-statement

# %% [markdown]
# Note how Python is so heavily driven by code indentation and whitespace. This means that code readability is a core part of the design of the Python language.
#
# Now let's start diving deeper by coding these sort of statements in Python!

# %% [markdown]
# ---

# %% [markdown]
# ## Conditional Statements

# %% [markdown]
# <code>if</code> Statements in Python allows us to tell the computer to perform alternative actions based on a certain set of results.
#
# Verbally, we can imagine we are telling the computer:
#
# "Hey if this case happens, perform some action"
#
# We can then expand the idea further with <code>elif</code> and <code>else</code> statements, which allow us to tell the computer:
#
# "Hey if this case happens, perform some action. Else, if another case happens, perform some other action. Else, if *none* of the above cases happened, perform this action."
#
# Let's go ahead and look at the syntax format for <code>if</code> statements to get a better idea of this:
#
#     if case1:
#         perform action1
#     elif case2:
#         perform action2
#     else:
#         perform action3

# %% [markdown]
# ### Example

# %% [markdown]
# Let's see a quick example of this:

# %%
if True:
    print('It was true!')
# Out:
# It was true!

# %% [markdown]
# Let's add in some else logic:

# %%
x = False

if x:
    print('x was True!')
else:
    print('I will be printed in any case where x is not true')
# Out:
# I will be printed in any case where x is not true

# %% [markdown]
# ### Multiple Branches

# %% [markdown]
# Let's get a fuller picture of how far <code>if</code>, <code>elif</code>, and <code>else</code> can take us!
#
# We write this out in a nested structure. Take note of how the <code>if</code>, <code>elif</code>, and <code>else</code> line up in the code. This can help you see what <code>if</code> is related to what <code>elif</code> or <code>else</code> statements.
#
# We'll reintroduce a comparison syntax for Python.

# %%
loc = 'Bank'

if loc == 'Auto Shop':
    print('Welcome to the Auto Shop!')
elif loc == 'Bank':
    print('Welcome to the bank!')
else:
    print('Where are you?')
# Out:
# Welcome to the bank!

# %% [markdown]
# Note how the nested <code>if</code> statements are each checked until a True boolean causes the nested code below it to run. You should also note that you can put in as many <code>elif</code> statements as you want before you close off with an <code>else</code>.
#
# Let's create two more simple examples for the <code>if</code>, <code>elif</code>, and <code>else</code> statements:

# %%
person = 'Sammy'

if person == 'Sammy':
    print('Welcome Sammy!')
else:
    print("Welcome, what's your name?")
# Out:
# Welcome Sammy!

# %%
person = 'George'

if person == 'Sammy':
    print('Welcome Sammy!')
elif person =='George':
    print('Welcome George!')
else:
    print("Welcome, what's your name?")
# Out:
# Welcome George!

# %% [markdown]
# **Indentation**<br>
# It is important to keep a good understanding of how indentation works in Python to maintain the structure and order of your code. We will touch on this topic again when we start building out functions!

# %% [markdown]
# ## While Loops

# %% [markdown]
# The <code>while</code> statement in Python is one of most general ways to perform iteration. A <code>while</code> statement will repeatedly execute a single statement or group of statements as long as the condition is true. The reason it is called a 'loop' is because the code statements are looped through over and over again until the condition is no longer met.
#
# The general format of a while loop is:
#
#     while test:
#         code statements
#     else:
#         final code statements
#
# Let’s look at a few simple <code>while</code> loops in action.

# %%
x = 0

while x < 10:
    print('x is currently: ',x)
    print(' x is still less than 10, adding 1 to x')
    x+=1
# Out:
# x is currently:  0
#  x is still less than 10, adding 1 to x
# x is currently:  1
#  x is still less than 10, adding 1 to x
# x is currently:  2
#  x is still less than 10, adding 1 to x
# x is currently:  3
#  x is still less than 10, adding 1 to x
# x is currently:  4
#  x is still less than 10, adding 1 to x
# x is currently:  5
#  x is still less than 10, adding 1 to x
# x is currently:  6
#  x is still less than 10, adding 1 to x
# x is currently:  7
#  x is still less than 10, adding 1 to x
# x is currently:  8
#  x is still less than 10, adding 1 to x
# x is currently:  9
#  x is still less than 10, adding 1 to x

# %%
x = 11

while x > 10:
    print('x is currently: ', x)
    print(' x is still less than 10, adding 1 to x')
    x += 1
# Out:
# x is currently:  11
#  x is still less than 10, adding 1 to x
# x is currently:  12
#  x is still less than 10, adding 1 to x
# x is currently:  13
#  x is still less than 10, adding 1 to x
# x is currently:  14
#  x is still less than 10, adding 1 to x
# x is currently:  15
#  x is still less than 10, adding 1 to x
# x is currently:  16
#  x is still less than 10, adding 1 to x
# x is currently:  17
#  x is still less than 10, adding 1 to x
# x is currently:  18
#  x is still less than 10, adding 1 to x
# x is currently:  19
#  x is still less than 10, adding 1 to x
# x is currently:  20
#  x is still less than 10, adding 1 to x
# x is currently:  21
#  x is still less than 10, adding 1 to x
# x is currently:  22
#  x is still less than 10, adding 1 to x
# x is currently:  23
#  x is still less than 10, adding 1 to x
# x is currently:  24
#  x is still less than 10, adding 1 to x
# x is currently:  25
#  x is still less than 10, adding 1 to x
# x is currently:  26
#  x is still less than 10, adding 1 to x
# x is currently:  27
#  x is still less than 10, adding 1 to x
# x is currently:  28
#  x is still less than 10, adding 1 to x
# x is currently:  29
#  x is still less than 10, adding 1 to x
# x is currently:  30
#  x is still less than 10, adding 1 to x
# x is currently:  31
#  x is still less than 10, adding 1 to x
# x is currently:  32
#  x is still less than 10, adding 1 to x
# x is currently:  33
#  x is still less than 10, adding 1 to x
# x is currently:  34
#  x is still less than 10, adding 1 to x
# x is currently:  35
#  x is still less than 10, adding 1 to x
# x is currently:  36
#  x is still less than 10, adding 1 to x
# x is currently:  37
#  x is still less than 10, adding 1 to x
# x is currently:  38
#  x is still less than 10, adding 1 to x
# x is currently:  39
#  x is still less than 10, adding 1 to x
# x is currently:  40
#  x is still less than 10, adding 1 to x
# x is currently:  41
#  x is still less than 10, adding 1 to x
# x is currently:  42
#  x is still less than 10, adding 1 to x
# x is currently:  43
#  x is still less than 10, adding 1 to x
# x is currently:  44
#  x is still less than 10, adding 1 to x
# x is currently:  45
#  x is still less than 10, adding 1 to x
# x is currently:  46
#  x is still less than 10, adding 1 to x
# x is currently:  47
#  x is still less than 10, adding 1 to x
# x is currently:  48
#  x is still less than 10, adding 1 to x
# x is currently:  49
#  x is still less than 10, adding 1 to x
# x is currently:  50
#  x is still less than 10, adding 1 to x
# x is currently:  51
#  x is still less than 10, adding 1 to x
# x is currently:  52
#  x is still less than 10, adding 1 to x
# x is currently:  53
#  x is still less than 10, adding 1 to x
# x is currently:  54
#  x is still less than 10, adding 1 to x
# x is currently:  55
#  x is still less than 10, adding 1 to x
# x is currently:  56
#  x is still less than 10, adding 1 to x
# x is currently:  57
#  x is still less than 10, adding 1 to x
# x is currently:  58
#  x is still less than 10, adding 1 to x
# x is currently:  59
#  x is still less than 10, adding 1 to x
# x is currently:  60
#  x is still less than 10, adding 1 to x
# x is currently:  61
#  x is still less than 10, adding 1 to x
# x is currently:  62
#  x is still less than 10, adding 1 to x
# x is currently:  63
#  x is still less than 10, adding 1 to x
# x is currently:  64
#  x is still less than 10, adding 1 to x
# x is currently:  65
#  x is still less than 10, adding 1 to x
# x is currently:  66
#  x is still less than 10, adding 1 to x
# x is currently:  67
#  x is still less than 10, adding 1 to x
# x is currently:  68
#  x is still less than 10, adding 1 to x
# x is currently:  69
#  x is still less than 10, adding 1 to x
# x is currently:  70
#  x is still less than 10, adding 1 to x
# x is currently:  71
#  x is still less than 10, adding 1 to x
# x is currently:  72
#  x is still less than 10, adding 1 to x
# x is currently:  73
#  x is still less than 10, adding 1 to x
# x is currently:  74
#  x is still less than 10, adding 1 to x
# x is currently:  75
#  x is still less than 10, adding 1 to x
# x is currently:  76
#  x is still less than 10, adding 1 to x
# x is currently:  77
#  x is still less than 10, adding 1 to x
# x is currently:  78
#  x is still less than 10, adding 1 to x
# x is currently:  79
#  x is still less than 10, adding 1 to x
# x is currently:  80
#  x is still less than 10, adding 1 to x
# x is currently:  81
#  x is still less than 10, adding 1 to x
# x is currently:  82
#  x is still less than 10, adding 1 to x
# x is currently:  83
#  x is still less than 10, adding 1 to x
# x is currently:  84
#  x is still less than 10, adding 1 to x
# x is currently:  85
#  x is still less than 10, adding 1 to x
# x is currently:  86
#  x is still less than 10, adding 1 to x
# x is currently:  87
#  x is still less than 10, adding 1 to x
# x is currently:  88
#  x is still less than 10, adding 1 to x
# x is currently:  89
#  x is still less than 10, adding 1 to x
# x is currently:  90
#  x is still less than 10, adding 1 to x
# x is currently:  91
#  x is still less than 10, adding 1 to x
# x is currently:  92
#  x is still less than 10, adding 1 to x
# x is currently:  93
#  x is still less than 10, adding 1 to x
# x is currently:  94
#  x is still less than 10, adding 1 to x
# x is currently:  95
#  x is still less than 10, adding 1 to x
# x is currently:  96
#  x is still less than 10, adding 1 to x
# x is currently:  97
#  x is still less than 10, adding 1 to x
# x is currently:  98
#  x is still less than 10, adding 1 to x
# x is currently:  99
#  x is still less than 10, adding 1 to x
# x is currently:  100
#  x is still less than 10, adding 1 to x
# x is currently:  101
#  x is still less than 10, adding 1 to x
# x is currently:  102
#  x is still less than 10, adding 1 to x
# x is currently:  103
#  x is still less than 10, adding 1 to x
# x is currently:  104
#  x is still less than 10, adding 1 to x
# x is currently:  105
#  x is still less than 10, adding 1 to x
# x is currently:  106
#  x is still less than 10, adding 1 to x
# x is currently:  107
#  x is still less than 10, adding 1 to x
# x is currently:  108
#  x is still less than 10, adding 1 to x
# x is currently:  109
#  x is still less than 10, adding 1 to x
# x is currently:  110
#  x is still less than 10, adding 1 to x
# x is currently:  111
#  x is still less than 10, adding 1 to x
# x is currently:  112
#  x is still less than 10, adding 1 to x
# x is currently:  113
#  x is still less than 10, adding 1 to x
# x is currently:  114
#  x is still less than 10, adding 1 to x
# x is currently:  115
#  x is still less than 10, adding 1 to x
# x is currently:  116
#  x is still less than 10, adding 1 to x
# x is currently:  117
#  x is still less than 10, adding 1 to x
# x is currently:  118
#  x is still less than 10, adding 1 to x
# x is currently:  119
#  x is still less than 10, adding 1 to x
# x is currently:  120
#  x is still less than 10, adding 1 to x
# x is currently:  121
#  x is still less than 10, adding 1 to x
# x is currently:  122
#  x is still less than 10, adding 1 to x
# x is currently:  123
#  x is still less than 10, adding 1 to x
# x is currently:  124
#  x is still less than 10, adding 1 to x
# x is currently:  125
#  x is still less than 10, adding 1 to x
# x is currently:  126
#  x is still less than 10, adding 1 to x
# x is currently:  127
#  x is still less than 10, adding 1 to x
# x is currently:  128
#  x is still less than 10, adding 1 to x
# x is currently:  129
#  x is still less than 10, adding 1 to x
# x is currently:  130
#  x is still less than 10, adding 1 to x
# x is currently:  131
#  x is still less than 10, adding 1 to x
# x is currently:  132
#  x is still less than 10, adding 1 to x
# x is currently:  133
#  x is still less than 10, adding 1 to x
# x is currently:  134
#  x is still less than 10, adding 1 to x
# x is currently:  135
#  x is still less than 10, adding 1 to x
# x is currently:  136
#  x is still less than 10, adding 1 to x
# x is currently:  137
#  x is still less than 10, adding 1 to x
# x is currently:  138
#  x is still less than 10, adding 1 to x
# x is currently:  139
#  x is still less than 10, adding 1 to x
# x is currently:  140
#  x is still less than 10, adding 1 to x
# x is currently:  141
#  x is still less than 10, adding 1 to x
# x is currently:  142
#  x is still less than 10, adding 1 to x
# x is currently:  143
#  x is still less than 10, adding 1 to x
# x is currently:  144
#  x is still less than 10, adding 1 to x
# x is currently:  145
#  x is still less than 10, adding 1 to x
# x is currently:  146
#  x is still less than 10, adding 1 to x
# x is currently:  147
#  x is still less than 10, adding 1 to x
# x is currently:  148
#  x is still less than 10, adding 1 to x
# x is currently:  149
#  x is still less than 10, adding 1 to x
# x is currently:  150
#  x is still less than 10, adding 1 to x
# x is currently:  151
#  x is still less than 10, adding 1 to x
# x is currently:  152
#  x is still less than 10, adding 1 to x
# x is currently:  153
#  x is still less than 10, adding 1 to x
# x is currently:  154
#  x is still less than 10, adding 1 to x
# x is currently:  155
#  x is still less than 10, adding 1 to x
# x is currently:  156
#  x is still less than 10, adding 1 to x
# x is currently:  157
#  x is still less than 10, adding 1 to x
# x is currently:  158
#  x is still less than 10, adding 1 to x
# x is currently:  159
#  x is still less than 10, adding 1 to x
# x is currently:  160
#  x is still less than 10, adding 1 to x
# x is currently:  161
#  x is still less than 10, adding 1 to x
# x is currently:  162
#  x is still less than 10, adding 1 to x
# x is currently:  163
#  x is still less than 10, adding 1 to x
# x is currently:  164
#  x is still less than 10, adding 1 to x
# x is currently:  165
#  x is still less than 10, adding 1 to x
# x is currently:  166
#  x is still less than 10, adding 1 to x
# x is currently:  167
#  x is still less than 10, adding 1 to x
# x is currently:  168
#  x is still less than 10, adding 1 to x
# x is currently:  169
#  x is still less than 10, adding 1 to x
# x is currently:  170
#  x is still less than 10, adding 1 to x
# x is currently:  171
#  x is still less than 10, adding 1 to x
# x is currently:  172
#  x is still less than 10, adding 1 to x
# x is currently:  173
#  x is still less than 10, adding 1 to x
# x is currently:  174
#  x is still less than 10, adding 1 to x
# x is currently:  175
#  x is still less than 10, adding 1 to x
# x is currently:  176
#  x is still less than 10, adding 1 to x
# x is currently:  177
#  x is still less than 10, adding 1 to x
# x is currently:  178
#  x is still less than 10, adding 1 to x
# x is currently:  179
#  x is still less than 10, adding 1 to x
# x is currently:  180
#  x is still less than 10, adding 1 to x
# x is currently:  181
#  x is still less than 10, adding 1 to x
# x is currently:  182
#  x is still less than 10, adding 1 to x
# x is currently:  183
#  x is still less than 10, adding 1 to x
# x is currently:  184
#  x is still less than 10, adding 1 to x
# x is currently:  185
#  x is still less than 10, adding 1 to x
# x is currently:  186
#  x is still less than 10, adding 1 to x
# x is currently:  187
#  x is still less than 10, adding 1 to x
# x is currently:  188
#  x is still less than 10, adding 1 to x
# x is currently:  189
#  x is still less than 10, adding 1 to x
# x is currently:  190
#  x is still less than 10, adding 1 to x
# x is currently:  191
#  x is still less than 10, adding 1 to x
# x is currently:  192
#  x is still less than 10, adding 1 to x
# x is currently:  193
#  x is still less than 10, adding 1 to x
# x is currently:  194
#  x is still less than 10, adding 1 to x
# x is currently:  195
#  x is still less than 10, adding 1 to x
# x is currently:  196
#  x is still less than 10, adding 1 to x
# x is currently:  197
#  x is still less than 10, adding 1 to x
# x is currently:  198
#  x is still less than 10, adding 1 to x
# x is currently:  199
#  x is still less than 10, adding 1 to x
# x is currently:  200
#  x is still less than 10, adding 1 to x
# x is currently:  201
#  x is still less than 10, adding 1 to x
# x is currently:  202
#  x is still less than 10, adding 1 to x
# x is currently:  203
#  x is still less than 10, adding 1 to x
# x is currently:  204
#  x is still less than 10, adding 1 to x
# x is currently:  205
#  x is still less than 10, adding 1 to x
# x is currently:  206
#  x is still less than 10, adding 1 to x
# x is currently:  207
#  x is still less than 10, adding 1 to x
# x is currently:  208
#  x is still less than 10, adding 1 to x
# x is currently:  209
#  x is still less than 10, adding 1 to x
# x is currently:  210
#  x is still less than 10, adding 1 to x
# x is currently:  211
#  x is still less than 10, adding 1 to x
# x is currently:  212
#  x is still less than 10, adding 1 to x
# x is currently:  213
#  x is still less than 10, adding 1 to x
# x is currently:  214
#  x is still less than 10, adding 1 to x
# x is currently:  215
#  x is still less than 10, adding 1 to x
# x is currently:  216
#  x is still less than 10, adding 1 to x
# x is currently:  217
#  x is still less than 10, adding 1 to x
# x is currently:  218
#  x is still less than 10, adding 1 to x
# x is currently:  219
#  x is still less than 10, adding 1 to x
# x is currently:  220
#  x is still less than 10, adding 1 to x
# x is currently:  221
#  x is still less than 10, adding 1 to x
# x is currently:  222
#  x is still less than 10, adding 1 to x
# x is currently:  223
#  x is still less than 10, adding 1 to x
# x is currently:  224
#  x is still less than 10, adding 1 to x
# x is currently:  225
#  x is still less than 10, adding 1 to x
# x is currently:  226
#  x is still less than 10, adding 1 to x
# x is currently:  227
#  x is still less than 10, adding 1 to x
# x is currently:  228
#  x is still less than 10, adding 1 to x
# x is currently:  229
#  x is still less than 10, adding 1 to x
# x is currently:  230
#  x is still less than 10, adding 1 to x
# x is currently:  231
#  x is still less than 10, adding 1 to x
# x is currently:  232
#  x is still less than 10, adding 1 to x
# x is currently:  233
#  x is still less than 10, adding 1 to x
# x is currently:  234
#  x is still less than 10, adding 1 to x
# x is currently:  235
#  x is still less than 10, adding 1 to x
# x is currently:  236
#  x is still less than 10, adding 1 to x
# x is currently:  237
#  x is still less than 10, adding 1 to x
# x is currently:  238
#  x is still less than 10, adding 1 to x
# x is currently:  239
#  x is still less than 10, adding 1 to x
# x is currently:  240
#  x is still less than 10, adding 1 to x
# x is currently:  241
#  x is still less than 10, adding 1 to x
# x is currently:  242
#  x is still less than 10, adding 1 to x
# x is currently:  243
#  x is still less than 10, adding 1 to x
# x is currently:  244
#  x is still less than 10, adding 1 to x
# x is currently:  245
#  x is still less than 10, adding 1 to x
# x is currently:  246
#  x is still less than 10, adding 1 to x
# x is currently:  247
#  x is still less than 10, adding 1 to x
# x is currently:  248
#  x is still less than 10, adding 1 to x
# x is currently:  249
#  x is still less than 10, adding 1 to x
# x is currently:  250
#  x is still less than 10, adding 1 to x
# x is currently:  251
#  x is still less than 10, adding 1 to x
# x is currently:  252
#  x is still less than 10, adding 1 to x
# x is currently:  253
#  x is still less than 10, adding 1 to x
# x is currently:  254
#  x is still less than 10, adding 1 to x
# x is currently:  255
#  x is still less than 10, adding 1 to x
# x is currently:  256
#  x is still less than 10, adding 1 to x
# x is currently:  257
#  x is still less than 10, adding 1 to x
# x is currently:  258
#  x is still less than 10, adding 1 to x
# x is currently:  259
#  x is still less than 10, adding 1 to x
# x is currently:  260
#  x is still less than 10, adding 1 to x
# x is currently:  261
#  x is still less than 10, adding 1 to x
# x is currently:  262
#  x is still less than 10, adding 1 to x
# x is currently:  263
#  x is still less than 10, adding 1 to x
# x is currently:  264
#  x is still less than 10, adding 1 to x
# x is currently:  265
#  x is still less than 10, adding 1 to x
# x is currently:  266
#  x is still less than 10, adding 1 to x
# x is currently:  267
#  x is still less than 10, adding 1 to x
# x is currently:  268
#  x is still less than 10, adding 1 to x
# x is currently:  269
#  x is still less than 10, adding 1 to x
# x is currently:  270
#  x is still less than 10, adding 1 to x
# x is currently:  271
#  x is still less than 10, adding 1 to x
# x is currently:  272
#  x is still less than 10, adding 1 to x
# x is currently:  273
#  x is still less than 10, adding 1 to x
# x is currently:  274
#  x is still less than 10, adding 1 to x
# x is currently:  275
#  x is still less than 10, adding 1 to x
# x is currently:  276
#  x is still less than 10, adding 1 to x
# x is currently:  277
#  x is still less than 10, adding 1 to x
# x is currently:  278
#  x is still less than 10, adding 1 to x
# x is currently:  279
#  x is still less than 10, adding 1 to x
# x is currently:  280
#  x is still less than 10, adding 1 to x
# x is currently:  281
#  x is still less than 10, adding 1 to x
# x is currently:  282
#  x is still less than 10, adding 1 to x
# x is currently:  283
#  x is still less than 10, adding 1 to x
# x is currently:  284
#  x is still less than 10, adding 1 to x
# x is currently:  285
#  x is still less than 10, adding 1 to x
# x is currently:  286
#  x is still less than 10, adding 1 to x
# x is currently:  287
#  x is still less than 10, adding 1 to x
# x is currently:  288
#  x is still less than 10, adding 1 to x
# x is currently:  289
#  x is still less than 10, adding 1 to x
# x is currently:  290
#  x is still less than 10, adding 1 to x
# x is currently:  291
#  x is still less than 10, adding 1 to x
# x is currently:  292
#  x is still less than 10, adding 1 to x
# x is currently:  293
#  x is still less than 10, adding 1 to x
# x is currently:  294
#  x is still less than 10, adding 1 to x
# x is currently:  295
#  x is still less than 10, adding 1 to x
# x is currently:  296
#  x is still less than 10, adding 1 to x
# x is currently:  297
#  x is still less than 10, adding 1 to x
# x is currently:  298
#  x is still less than 10, adding 1 to x
# x is currently:  299
#  x is still less than 10, adding 1 to x
# x is currently:  300
#  x is still less than 10, adding 1 to x
# x is currently:  301
#  x is still less than 10, adding 1 to x
# x is currently:  302
#  x is still less than 10, adding 1 to x
# x is currently:  303
#  x is still less than 10, adding 1 to x
# x is currently:  304
#  x is still less than 10, adding 1 to x
# x is currently:  305
#  x is still less than 10, adding 1 to x
# x is currently:  306
#  x is still less than 10, adding 1 to x
# x is currently:  307
#  x is still less than 10, adding 1 to x
# x is currently:  308
#  x is still less than 10, adding 1 to x
# x is currently:  309
#  x is still less than 10, adding 1 to x
# x is currently:  310
#  x is still less than 10, adding 1 to x
# x is currently:  311
#  x is still less than 10, adding 1 to x
# x is currently:  312
#  x is still less than 10, adding 1 to x
# x is currently:  313
#  x is still less than 10, adding 1 to x
# x is currently:  314
#  x is still less than 10, adding 1 to x
# x is currently:  315
#  x is still less than 10, adding 1 to x
# x is currently:  316
#  x is still less than 10, adding 1 to x
# x is currently:  317
#  x is still less than 10, adding 1 to x
# x is currently:  318
#  x is still less than 10, adding 1 to x
# x is currently:  319
#  x is still less than 10, adding 1 to x
# x is currently:  320
#  x is still less than 10, adding 1 to x
# x is currently:  321
#  x is still less than 10, adding 1 to x
# x is currently:  322
#  x is still less than 10, adding 1 to x
# x is currently:  323
#  x is still less than 10, adding 1 to x
# x is currently:  324
#  x is still less than 10, adding 1 to x
# x is currently:  325
#  x is still less than 10, adding 1 to x
# x is currently:  326
#  x is still less than 10, adding 1 to x
# x is currently:  327
#  x is still less than 10, adding 1 to x
# x is currently:  328
#  x is still less than 10, adding 1 to x
# x is currently:  329
#  x is still less than 10, adding 1 to x
# x is currently:  330
#  x is still less than 10, adding 1 to x
# x is currently:  331
#  x is still less than 10, adding 1 to x
# x is currently:  332
#  x is still less than 10, adding 1 to x
# x is currently:  333
#  x is still less than 10, adding 1 to x
# x is currently:  334
#  x is still less than 10, adding 1 to x
# x is currently:  335
#  x is still less than 10, adding 1 to x
# x is currently:  336
#  x is still less than 10, adding 1 to x
# x is currently:  337
#  x is still less than 10, adding 1 to x
# x is currently:  338
#  x is still less than 10, adding 1 to x
# x is currently:  339
#  x is still less than 10, adding 1 to x
# x is currently:  340
#  x is still less than 10, adding 1 to x
# x is currently:  341
#  x is still less than 10, adding 1 to x
# x is currently:  342
#  x is still less than 10, adding 1 to x
# x is currently:  343
#  x is still less than 10, adding 1 to x
# x is currently:  344
#  x is still less than 10, adding 1 to x
# x is currently:  345
#  x is still less than 10, adding 1 to x
# x is currently:  346
#  x is still less than 10, adding 1 to x
# x is currently:  347
#  x is still less than 10, adding 1 to x
# x is currently:  348
#  x is still less than 10, adding 1 to x
# x is currently:  349
#  x is still less than 10, adding 1 to x
# x is currently:  350
#  x is still less than 10, adding 1 to x
# x is currently:  351
#  x is still less than 10, adding 1 to x
# x is currently:  352
#  x is still less than 10, adding 1 to x
# x is currently:  353
#  x is still less than 10, adding 1 to x
# x is currently:  354
#  x is still less than 10, adding 1 to x
# x is currently:  355
#  x is still less than 10, adding 1 to x
# x is currently:  356
#  x is still less than 10, adding 1 to x
# x is currently:  357
#  x is still less than 10, adding 1 to x
# x is currently:  358
#  x is still less than 10, adding 1 to x
# x is currently:  359
#  x is still less than 10, adding 1 to x
# x is currently:  360
#  x is still less than 10, adding 1 to x
# x is currently:  361
#  x is still less than 10, adding 1 to x
# x is currently:  362
#  x is still less than 10, adding 1 to x
# x is currently:  363
#  x is still less than 10, adding 1 to x
# x is currently:  364
#  x is still less than 10, adding 1 to x
# x is currently:  365
#  x is still less than 10, adding 1 to x
# x is currently:  366
#  x is still less than 10, adding 1 to x
# x is currently:  367
#  x is still less than 10, adding 1 to x
# x is currently:  368
#  x is still less than 10, adding 1 to x
# x is currently:  369
#  x is still less than 10, adding 1 to x
# x is currently:  370
#  x is still less than 10, adding 1 to x
# x is currently:  371
#  x is still less than 10, adding 1 to x
# x is currently:  372
#  x is still less than 10, adding 1 to x
# x is currently:  373
#  x is still less than 10, adding 1 to x
# x is currently:  374
#  x is still less than 10, adding 1 to x
# x is currently:  375
#  x is still less than 10, adding 1 to x
# x is currently:  376
#  x is still less than 10, adding 1 to x
# x is currently:  377
#  x is still less than 10, adding 1 to x
# x is currently:  378
#  x is still less than 10, adding 1 to x
# x is currently:  379
#  x is still less than 10, adding 1 to x
# x is currently:  380
#  x is still less than 10, adding 1 to x
# x is currently:  381
#  x is still less than 10, adding 1 to x
# x is currently:  382
#  x is still less than 10, adding 1 to x
# x is currently:  383
#  x is still less than 10, adding 1 to x
# x is currently:  384
#  x is still less than 10, adding 1 to x
# x is currently:  385
#  x is still less than 10, adding 1 to x
# x is currently:  386
#  x is still less than 10, adding 1 to x
# x is currently:  387
#  x is still less than 10, adding 1 to x
# x is currently:  388
#  x is still less than 10, adding 1 to x
# x is currently:  389
#  x is still less than 10, adding 1 to x
# x is currently:  390
#  x is still less than 10, adding 1 to x
# x is currently:  391
#  x is still less than 10, adding 1 to x
# x is currently:  392
#  x is still less than 10, adding 1 to x
# x is currently:  393
#  x is still less than 10, adding 1 to x
# x is currently:  394
#  x is still less than 10, adding 1 to x
# x is currently:  395
#  x is still less than 10, adding 1 to x
# x is currently:  396
#  x is still less than 10, adding 1 to x
# x is currently:  397
#  x is still less than 10, adding 1 to x
# x is currently:  398
#  x is still less than 10, adding 1 to x
# x is currently:  399
#  x is still less than 10, adding 1 to x
# x is currently:  400
#  x is still less than 10, adding 1 to x
# x is currently:  401
#  x is still less than 10, adding 1 to x
# x is currently:  402
#  x is still less than 10, adding 1 to x
# x is currently:  403
#  x is still less than 10, adding 1 to x
# x is currently:  404
#  x is still less than 10, adding 1 to x
# x is currently:  405
#  x is still less than 10, adding 1 to x
# x is currently:  406
#  x is still less than 10, adding 1 to x
# x is currently:  407
#  x is still less than 10, adding 1 to x
# x is currently:  408
#  x is still less than 10, adding 1 to x
# x is currently:  409
#  x is still less than 10, adding 1 to x
# x is currently:  410
#  x is still less than 10, adding 1 to x
# x is currently:  411
#  x is still less than 10, adding 1 to x
# x is currently:  412
#  x is still less than 10, adding 1 to x
# x is currently:  413
#  x is still less than 10, adding 1 to x
# x is currently:  414
#  x is still less than 10, adding 1 to x
# x is currently:  415
#  x is still less than 10, adding 1 to x
# x is currently:  416
#  x is still less than 10, adding 1 to x
# x is currently:  417
#  x is still less than 10, adding 1 to x
# x is currently:  418
#  x is still less than 10, adding 1 to x
# x is currently:  419
#  x is still less than 10, adding 1 to x
# x is currently:  420
#  x is still less than 10, adding 1 to x
# x is currently:  421
#  x is still less than 10, adding 1 to x
# x is currently:  422
#  x is still less than 10, adding 1 to x
# x is currently:  423
#  x is still less than 10, adding 1 to x
# x is currently:  424
#  x is still less than 10, adding 1 to x
# x is currently:  425
#  x is still less than 10, adding 1 to x
# x is currently:  426
#  x is still less than 10, adding 1 to x
# x is currently:  427
#  x is still less than 10, adding 1 to x
# x is currently:  428
#  x is still less than 10, adding 1 to x
# x is currently:  429
#  x is still less than 10, adding 1 to x
# x is currently:  430
#  x is still less than 10, adding 1 to x
# x is currently:  431
#  x is still less than 10, adding 1 to x
# x is currently:  432
#  x is still less than 10, adding 1 to x
# x is currently:  433
#  x is still less than 10, adding 1 to x
# x is currently:  434
#  x is still less than 10, adding 1 to x
# x is currently:  435
#  x is still less than 10, adding 1 to x
# x is currently:  436
#  x is still less than 10, adding 1 to x
# x is currently:  437
#  x is still less than 10, adding 1 to x
# x is currently:  438
#  x is still less than 10, adding 1 to x
# x is currently:  439
#  x is still less than 10, adding 1 to x
# x is currently:  440
#  x is still less than 10, adding 1 to x
# x is currently:  441
#  x is still less than 10, adding 1 to x
# x is currently:  442
#  x is still less than 10, adding 1 to x
# x is currently:  443
#  x is still less than 10, adding 1 to x
# x is currently:  444
#  x is still less than 10, adding 1 to x
# x is currently:  445
#  x is still less than 10, adding 1 to x
# x is currently:  446
#  x is still less than 10, adding 1 to x
# x is currently:  447
#  x is still less than 10, adding 1 to x
# x is currently:  448
#  x is still less than 10, adding 1 to x
# x is currently:  449
#  x is still less than 10, adding 1 to x
# x is currently:  450
#  x is still less than 10, adding 1 to x
# x is currently:  451
#  x is still less than 10, adding 1 to x
# x is currently:  452
#  x is still less than 10, adding 1 to x
# x is currently:  453
#  x is still less than 10, adding 1 to x
# x is currently:  454
#  x is still less than 10, adding 1 to x
# x is currently:  455
#  x is still less than 10, adding 1 to x
# x is currently:  456
#  x is still less than 10, adding 1 to x
# x is currently:  457
#  x is still less than 10, adding 1 to x
# x is currently:  458
#  x is still less than 10, adding 1 to x
# x is currently:  459
#  x is still less than 10, adding 1 to x
# x is currently:  460
#  x is still less than 10, adding 1 to x
# x is currently:  461
#  x is still less than 10, adding 1 to x
# x is currently:  462
#  x is still less than 10, adding 1 to x
# x is currently:  463
#  x is still less than 10, adding 1 to x
# x is currently:  464
#  x is still less than 10, adding 1 to x
# x is currently:  465
#  x is still less than 10, adding 1 to x
# x is currently:  466
#  x is still less than 10, adding 1 to x
# x is currently:  467
#  x is still less than 10, adding 1 to x
# x is currently:  468
#  x is still less than 10, adding 1 to x
# x is currently:  469
#  x is still less than 10, adding 1 to x
# x is currently:  470
#  x is still less than 10, adding 1 to x
# x is currently:  471
#  x is still less than 10, adding 1 to x
# x is currently:  472
#  x is still less than 10, adding 1 to x
# x is currently:  473
#  x is still less than 10, adding 1 to x
# x is currently:  474
#  x is still less than 10, adding 1 to x
# x is currently:  475
#  x is still less than 10, adding 1 to x
# x is currently:  476
#  x is still less than 10, adding 1 to x
# x is currently:  477
#  x is still less than 10, adding 1 to x
# x is currently:  478
#  x is still less than 10, adding 1 to x
# x is currently:  479
#  x is still less than 10, adding 1 to x
# x is currently:  480
#  x is still less than 10, adding 1 to x
# x is currently:  481
#  x is still less than 10, adding 1 to x
# x is currently:  482
#  x is still less than 10, adding 1 to x
# x is currently:  483
#  x is still less than 10, adding 1 to x
# x is currently:  484
#  x is still less than 10, adding 1 to x
# x is currently:  485
#  x is still less than 10, adding 1 to x
# x is currently:  486
#  x is still less than 10, adding 1 to x
# x is currently:  487
#  x is still less than 10, adding 1 to x
# x is currently:  488
#  x is still less than 10, adding 1 to x
# x is currently:  489
#  x is still less than 10, adding 1 to x
# x is currently:  490
#  x is still less than 10, adding 1 to x
# x is currently:  491
#  x is still less than 10, adding 1 to x
# x is currently:  492
#  x is still less than 10, adding 1 to x
# x is currently:  493
#  x is still less than 10, adding 1 to x
# x is currently:  494
#  x is still less than 10, adding 1 to x
# x is currently:  495
#  x is still less than 10, adding 1 to x
# x is currently:  496
#  x is still less than 10, adding 1 to x
# x is currently:  497
#  x is still less than 10, adding 1 to x
# x is currently:  498
#  x is still less than 10, adding 1 to x
# x is currently:  499
#  x is still less than 10, adding 1 to x
# x is currently:  500
#  x is still less than 10, adding 1 to x
# x is currently:  501
#  x is still less than 10, adding 1 to x
# x is currently:  502
#  x is still less than 10, adding 1 to x
# x is currently:  503
#  x is still less than 10, adding 1 to x
# x is currently:  504
#  x is still less than 10, adding 1 to x
# x is currently:  505
#  x is still less than 10, adding 1 to x
# x is currently:  506
#  x is still less than 10, adding 1 to x
# x is currently:  507
#  x is still less than 10, adding 1 to x
# x is currently:  508
#  x is still less than 10, adding 1 to x
# x is currently:  509
#  x is still less than 10, adding 1 to x
# x is currently:  510
#  x is still less than 10, adding 1 to x
# x is currently:  511
#  x is still less than 10, adding 1 to x
# x is currently:  512
#  x is still less than 10, adding 1 to x
# x is currently:  513
#  x is still less than 10, adding 1 to x
# x is currently:  514
#  x is still less than 10, adding 1 to x
# x is currently:  515
#  x is still less than 10, adding 1 to x
# x is currently:  516
#  x is still less than 10, adding 1 to x
# x is currently:  517
#  x is still less than 10, adding 1 to x
# x is currently:  518
#  x is still less than 10, adding 1 to x
# x is currently:  519
#  x is still less than 10, adding 1 to x
# x is currently:  520
#  x is still less than 10, adding 1 to x
# x is currently:  521
#  x is still less than 10, adding 1 to x
# x is currently:  522
#  x is still less than 10, adding 1 to x
# x is currently:  523
#  x is still less than 10, adding 1 to x
# x is currently:  524
#  x is still less than 10, adding 1 to x
# x is currently:  525
#  x is still less than 10, adding 1 to x
# x is currently:  526
#  x is still less than 10, adding 1 to x
# x is currently:  527
#  x is still less than 10, adding 1 to x
# x is currently:  528
#  x is still less than 10, adding 1 to x
# x is currently:  529
#  x is still less than 10, adding 1 to x
# x is currently:  530
#  x is still less than 10, adding 1 to x
# x is currently:  531
#  x is still less than 10, adding 1 to x
# x is currently:  532
#  x is still less than 10, adding 1 to x
# x is currently:  533
#  x is still less than 10, adding 1 to x
# x is currently:  534
#  x is still less than 10, adding 1 to x
# x is currently:  535
#  x is still less than 10, adding 1 to x
# x is currently:  536
#  x is still less than 10, adding 1 to x
# x is currently:  537
#  x is still less than 10, adding 1 to x
# x is currently:  538
#  x is still less than 10, adding 1 to x
# x is currently:  539
#  x is still less than 10, adding 1 to x
# x is currently:  540
#  x is still less than 10, adding 1 to x
# x is currently:  541
#  x is still less than 10, adding 1 to x
# x is currently:  542
#  x is still less than 10, adding 1 to x
# x is currently:  543
#  x is still less than 10, adding 1 to x
# x is currently:  544
#  x is still less than 10, adding 1 to x
# x is currently:  545
#  x is still less than 10, adding 1 to x
# x is currently:  546
#  x is still less than 10, adding 1 to x
# x is currently:  547
#  x is still less than 10, adding 1 to x
# x is currently:  548
#  x is still less than 10, adding 1 to x
# x is currently:  549
#  x is still less than 10, adding 1 to x
# x is currently:  550
#  x is still less than 10, adding 1 to x
# x is currently:  551
#  x is still less than 10, adding 1 to x
# x is currently:  552
#  x is still less than 10, adding 1 to x
# x is currently:  553
#  x is still less than 10, adding 1 to x
# x is currently:  554
#  x is still less than 10, adding 1 to x
# x is currently:  555
#  x is still less than 10, adding 1 to x
# x is currently:  556
#  x is still less than 10, adding 1 to x
# x is currently:  557
#  x is still less than 10, adding 1 to x
# x is currently:  558
#  x is still less than 10, adding 1 to x
# x is currently:  559
#  x is still less than 10, adding 1 to x
# x is currently:  560
#  x is still less than 10, adding 1 to x
# x is currently:  561
#  x is still less than 10, adding 1 to x
# x is currently:  562
#  x is still less than 10, adding 1 to x
# x is currently:  563
#  x is still less than 10, adding 1 to x
# x is currently:  564
#  x is still less than 10, adding 1 to x
# x is currently:  565
#  x is still less than 10, adding 1 to x
# x is currently:  566
#  x is still less than 10, adding 1 to x
# x is currently:  567
#  x is still less than 10, adding 1 to x
# x is currently:  568
#  x is still less than 10, adding 1 to x
# x is currently:  569
#  x is still less than 10, adding 1 to x
# x is currently:  570
#  x is still less than 10, adding 1 to x
# x is currently:  571
#  x is still less than 10, adding 1 to x
# x is currently:  572
#  x is still less than 10, adding 1 to x
# x is currently:  573
#  x is still less than 10, adding 1 to x
# x is currently:  574
#  x is still less than 10, adding 1 to x
# x is currently:  575
#  x is still less than 10, adding 1 to x
# x is currently:  576
#  x is still less than 10, adding 1 to x
# x is currently:  577
#  x is still less than 10, adding 1 to x
# x is currently:  578
#  x is still less than 10, adding 1 to x
# x is currently:  579
#  x is still less than 10, adding 1 to x
# x is currently:  580
#  x is still less than 10, adding 1 to x
# x is currently:  581
#  x is still less than 10, adding 1 to x
# x is currently:  582
#  x is still less than 10, adding 1 to x
# x is currently:  583
#  x is still less than 10, adding 1 to x
# x is currently:  584
#  x is still less than 10, adding 1 to x
# x is currently:  585
#  x is still less than 10, adding 1 to x
# x is currently:  586
#  x is still less than 10, adding 1 to x
# x is currently:  587
#  x is still less than 10, adding 1 to x
# x is currently:  588
#  x is still less than 10, adding 1 to x
# x is currently:  589
#  x is still less than 10, adding 1 to x
# x is currently:  590
#  x is still less than 10, adding 1 to x
# x is currently:  591
#  x is still less than 10, adding 1 to x
# x is currently:  592
#  x is still less than 10, adding 1 to x
# x is currently:  593
#  x is still less than 10, adding 1 to x
# x is currently:  594
#  x is still less than 10, adding 1 to x
# x is currently:  595
#  x is still less than 10, adding 1 to x
# x is currently:  596
#  x is still less than 10, adding 1 to x
# x is currently:  597
#  x is still less than 10, adding 1 to x
# x is currently:  598
#  x is still less than 10, adding 1 to x
# x is currently:  599
#  x is still less than 10, adding 1 to x
# x is currently:  600
#  x is still less than 10, adding 1 to x
# x is currently:  601
#  x is still less than 10, adding 1 to x
# x is currently:  602
#  x is still less than 10, adding 1 to x
# x is currently:  603
#  x is still less than 10, adding 1 to x
# x is currently:  604
#  x is still less than 10, adding 1 to x
# x is currently:  605
#  x is still less than 10, adding 1 to x
# x is currently:  606
#  x is still less than 10, adding 1 to x
# x is currently:  607
#  x is still less than 10, adding 1 to x
# x is currently:  608
#  x is still less than 10, adding 1 to x
# x is currently:  609
#  x is still less than 10, adding 1 to x
# x is currently:  610
#  x is still less than 10, adding 1 to x
# x is currently:  611
#  x is still less than 10, adding 1 to x
# x is currently:  612
#  x is still less than 10, adding 1 to x
# x is currently:  613
#  x is still less than 10, adding 1 to x
# x is currently:  614
#  x is still less than 10, adding 1 to x
# x is currently:  615
#  x is still less than 10, adding 1 to x
# x is currently:  616
#  x is still less than 10, adding 1 to x
# x is currently:  617
#  x is still less than 10, adding 1 to x
# x is currently:  618
#  x is still less than 10, adding 1 to x
# x is currently:  619
#  x is still less than 10, adding 1 to x
# x is currently:  620
#  x is still less than 10, adding 1 to x
# x is currently:  621
#  x is still less than 10, adding 1 to x
# x is currently:  622
#  x is still less than 10, adding 1 to x
# x is currently:  623
#  x is still less than 10, adding 1 to x
# x is currently:  624
#  x is still less than 10, adding 1 to x
# x is currently:  625
#  x is still less than 10, adding 1 to x
# x is currently:  626
#  x is still less than 10, adding 1 to x
# x is currently:  627
#  x is still less than 10, adding 1 to x
# x is currently:  628
#  x is still less than 10, adding 1 to x
# x is currently:  629
#  x is still less than 10, adding 1 to x
# x is currently:  630
#  x is still less than 10, adding 1 to x
# x is currently:  631
#  x is still less than 10, adding 1 to x
# x is currently:  632
#  x is still less than 10, adding 1 to x
# x is currently:  633
#  x is still less than 10, adding 1 to x
# x is currently:  634
#  x is still less than 10, adding 1 to x
# x is currently:  635
#  x is still less than 10, adding 1 to x
# x is currently:  636
#  x is still less than 10, adding 1 to x
# x is currently:  637
#  x is still less than 10, adding 1 to x
# x is currently:  638
#  x is still less than 10, adding 1 to x
# x is currently:  639
#  x is still less than 10, adding 1 to x
# x is currently:  640
#  x is still less than 10, adding 1 to x
# x is currently:  641
#  x is still less than 10, adding 1 to x
# x is currently:  642
#  x is still less than 10, adding 1 to x
# x is currently:  643
#  x is still less than 10, adding 1 to x
# x is currently:  644
#  x is still less than 10, adding 1 to x
# x is currently:  645
#  x is still less than 10, adding 1 to x
# x is currently:  646
#  x is still less than 10, adding 1 to x
# x is currently:  647
#  x is still less than 10, adding 1 to x
# x is currently:  648
#  x is still less than 10, adding 1 to x
# x is currently:  649
#  x is still less than 10, adding 1 to x
# x is currently:  650
#  x is still less than 10, adding 1 to x
# x is currently:  651
#  x is still less than 10, adding 1 to x
# x is currently:  652
#  x is still less than 10, adding 1 to x
# x is currently:  653
#  x is still less than 10, adding 1 to x
# x is currently:  654
#  x is still less than 10, adding 1 to x
# x is currently:  655
#  x is still less than 10, adding 1 to x
# x is currently:  656
#  x is still less than 10, adding 1 to x
# x is currently:  657
#  x is still less than 10, adding 1 to x
# x is currently:  658
#  x is still less than 10, adding 1 to x
# x is currently:  659
#  x is still less than 10, adding 1 to x
# x is currently:  660
#  x is still less than 10, adding 1 to x
# x is currently:  661
#  x is still less than 10, adding 1 to x
# x is currently:  662
#  x is still less than 10, adding 1 to x
# x is currently:  663
#  x is still less than 10, adding 1 to x
# x is currently:  664
#  x is still less than 10, adding 1 to x
# x is currently:  665
#  x is still less than 10, adding 1 to x
# x is currently:  666
#  x is still less than 10, adding 1 to x
# x is currently:  667
#  x is still less than 10, adding 1 to x
# x is currently:  668
#  x is still less than 10, adding 1 to x
# x is currently:  669
#  x is still less than 10, adding 1 to x
# x is currently:  670
#  x is still less than 10, adding 1 to x
# x is currently:  671
#  x is still less than 10, adding 1 to x
# x is currently:  672
#  x is still less than 10, adding 1 to x
# x is currently:  673
#  x is still less than 10, adding 1 to x
# x is currently:  674
#  x is still less than 10, adding 1 to x
# x is currently:  675
#  x is still less than 10, adding 1 to x
# x is currently:  676
#  x is still less than 10, adding 1 to x
# x is currently:  677
#  x is still less than 10, adding 1 to x
# x is currently:  678
#  x is still less than 10, adding 1 to x
# x is currently:  679
#  x is still less than 10, adding 1 to x
# x is currently:  680
#  x is still less than 10, adding 1 to x
# x is currently:  681
#  x is still less than 10, adding 1 to x
# x is currently:  682
#  x is still less than 10, adding 1 to x
# x is currently:  683
#  x is still less than 10, adding 1 to x
# x is currently:  684
#  x is still less than 10, adding 1 to x
# x is currently:  685
#  x is still less than 10, adding 1 to x
# x is currently:  686
#  x is still less than 10, adding 1 to x
# x is currently:  687
#  x is still less than 10, adding 1 to x
# x is currently:  688
#  x is still less than 10, adding 1 to x
# x is currently:  689
#  x is still less than 10, adding 1 to x
# x is currently:  690
#  x is still less than 10, adding 1 to x
# x is currently:  691
#  x is still less than 10, adding 1 to x
# x is currently:  692
#  x is still less than 10, adding 1 to x
# x is currently:  693
#  x is still less than 10, adding 1 to x
# x is currently:  694
#  x is still less than 10, adding 1 to x
# x is currently:  695
#  x is still less than 10, adding 1 to x
# x is currently:  696
#  x is still less than 10, adding 1 to x
# x is currently:  697
#  x is still less than 10, adding 1 to x
# x is currently:  698
#  x is still less than 10, adding 1 to x
# x is currently:  699
#  x is still less than 10, adding 1 to x
# x is currently:  700
#  x is still less than 10, adding 1 to x
# x is currently:  701
#  x is still less than 10, adding 1 to x
# x is currently:  702
#  x is still less than 10, adding 1 to x
# x is currently:  703
#  x is still less than 10, adding 1 to x
# x is currently:  704
#  x is still less than 10, adding 1 to x
# x is currently:  705
#  x is still less than 10, adding 1 to x
# x is currently:  706
#  x is still less than 10, adding 1 to x
# x is currently:  707
#  x is still less than 10, adding 1 to x
# x is currently:  708
#  x is still less than 10, adding 1 to x
# x is currently:  709
#  x is still less than 10, adding 1 to x
# x is currently:  710
#  x is still less than 10, adding 1 to x
# x is currently:  711
#  x is still less than 10, adding 1 to x
# x is currently:  712
#  x is still less than 10, adding 1 to x
# x is currently:  713
#  x is still less than 10, adding 1 to x
# x is currently:  714
#  x is still less than 10, adding 1 to x
# x is currently:  715
#  x is still less than 10, adding 1 to x
# x is currently:  716
#  x is still less than 10, adding 1 to x
# x is currently:  717
#  x is still less than 10, adding 1 to x
# x is currently:  718
#  x is still less than 10, adding 1 to x
# x is currently:  719
#  x is still less than 10, adding 1 to x
# x is currently:  720
#  x is still less than 10, adding 1 to x
# x is currently:  721
#  x is still less than 10, adding 1 to x
# x is currently:  722
#  x is still less than 10, adding 1 to x
# x is currently:  723
#  x is still less than 10, adding 1 to x
# x is currently:  724
#  x is still less than 10, adding 1 to x
# x is currently:  725
#  x is still less than 10, adding 1 to x
# x is currently:  726
#  x is still less than 10, adding 1 to x
# x is currently:  727
#  x is still less than 10, adding 1 to x
# x is currently:  728
#  x is still less than 10, adding 1 to x
# x is currently:  729
#  x is still less than 10, adding 1 to x
# x is currently:  730
#  x is still less than 10, adding 1 to x
# x is currently:  731
#  x is still less than 10, adding 1 to x
# x is currently:  732
#  x is still less than 10, adding 1 to x
# x is currently:  733
#  x is still less than 10, adding 1 to x
# x is currently:  734
#  x is still less than 10, adding 1 to x
# x is currently:  735
#  x is still less than 10, adding 1 to x
# x is currently:  736
#  x is still less than 10, adding 1 to x
# x is currently:  737
#  x is still less than 10, adding 1 to x
# x is currently:  738
#  x is still less than 10, adding 1 to x
# x is currently:  739
#  x is still less than 10, adding 1 to x
# x is currently:  740
#  x is still less than 10, adding 1 to x
# x is currently:  741
#  x is still less than 10, adding 1 to x
# x is currently:  742
#  x is still less than 10, adding 1 to x
# x is currently:  743
#  x is still less than 10, adding 1 to x
# x is currently:  744
#  x is still less than 10, adding 1 to x
# x is currently:  745
#  x is still less than 10, adding 1 to x
# x is currently:  746
#  x is still less than 10, adding 1 to x
# x is currently:  747
#  x is still less than 10, adding 1 to x
# x is currently:  748
#  x is still less than 10, adding 1 to x
# x is currently:  749
#  x is still less than 10, adding 1 to x
# x is currently:  750
#  x is still less than 10, adding 1 to x
# x is currently:  751
#  x is still less than 10, adding 1 to x
# x is currently:  752
#  x is still less than 10, adding 1 to x
# x is currently:  753
#  x is still less than 10, adding 1 to x
# x is currently:  754
#  x is still less than 10, adding 1 to x
# x is currently:  755
#  x is still less than 10, adding 1 to x
# x is currently:  756
#  x is still less than 10, adding 1 to x
# x is currently:  757
#  x is still less than 10, adding 1 to x
# x is currently:  758
#  x is still less than 10, adding 1 to x
# x is currently:  759
#  x is still less than 10, adding 1 to x
# x is currently:  760
#  x is still less than 10, adding 1 to x
# x is currently:  761
#  x is still less than 10, adding 1 to x
# x is currently:  762
#  x is still less than 10, adding 1 to x
# x is currently:  763
#  x is still less than 10, adding 1 to x
# x is currently:  764
#  x is still less than 10, adding 1 to x
# x is currently:  765
#  x is still less than 10, adding 1 to x
# x is currently:  766
#  x is still less than 10, adding 1 to x
# x is currently:  767
#  x is still less than 10, adding 1 to x
# x is currently:  768
#  x is still less than 10, adding 1 to x
# x is currently:  769
#  x is still less than 10, adding 1 to x
# x is currently:  770
#  x is still less than 10, adding 1 to x
# x is currently:  771
#  x is still less than 10, adding 1 to x
# x is currently:  772
#  x is still less than 10, adding 1 to x
# x is currently:  773
#  x is still less than 10, adding 1 to x
# x is currently:  774
#  x is still less than 10, adding 1 to x
# x is currently:  775
#  x is still less than 10, adding 1 to x
# x is currently:  776
#  x is still less than 10, adding 1 to x
# x is currently:  777
#  x is still less than 10, adding 1 to x
# x is currently:  778
#  x is still less than 10, adding 1 to x
# x is currently:  779
#  x is still less than 10, adding 1 to x
# x is currently:  780
#  x is still less than 10, adding 1 to x
# x is currently:  781
#  x is still less than 10, adding 1 to x
# x is currently:  782
#  x is still less than 10, adding 1 to x
# x is currently:  783
#  x is still less than 10, adding 1 to x
# x is currently:  784
#  x is still less than 10, adding 1 to x
# x is currently:  785
#  x is still less than 10, adding 1 to x
# x is currently:  786
#  x is still less than 10, adding 1 to x
# x is currently:  787
#  x is still less than 10, adding 1 to x
# x is currently:  788
#  x is still less than 10, adding 1 to x
# x is currently:  789
#  x is still less than 10, adding 1 to x
# x is currently:  790
#  x is still less than 10, adding 1 to x
# x is currently:  791
#  x is still less than 10, adding 1 to x
# x is currently:  792
#  x is still less than 10, adding 1 to x
# x is currently:  793
#  x is still less than 10, adding 1 to x
# x is currently:  794
#  x is still less than 10, adding 1 to x
# x is currently:  795
#  x is still less than 10, adding 1 to x
# x is currently:  796
#  x is still less than 10, adding 1 to x
# x is currently:  797
#  x is still less than 10, adding 1 to x
# x is currently:  798
#  x is still less than 10, adding 1 to x
# x is currently:  799
# ...
# x is currently:  14764
#  x is still less than 10, adding 1 to x
# x is currently:  14765
#  x is still less than 10, adding 1 to x
# x is currently:  14766
#  x is still less than 10, adding 1 to x
# x is currently:  14767
#  x is still less than 10, adding 1 to x
# x is currently:  14768
#  x is still less than 10, adding 1 to x
# x is currently:  14769
#  x is still less than 10, adding 1 to x
# x is currently:  14770
#  x is still less than 10, adding 1 to x
# x is currently:  14771
#  x is still less than 10, adding 1 to x
# x is currently:  14772
#  x is still less than 10, adding 1 to x
# x is currently:  14773
#  x is still less than 10, adding 1 to x
# x is currently:  14774
#  x is still less than 10, adding 1 to x
# x is currently:  14775
#  x is still less than 10, adding 1 to x
# x is currently:  14776
#  x is still less than 10, adding 1 to x
# x is currently:  14777
#  x is still less than 10, adding 1 to x
# x is currently:  14778
#  x is still less than 10, adding 1 to x
# x is currently:  14779
#  x is still less than 10, adding 1 to x
# x is currently:  14780
#  x is still less than 10, adding 1 to x
# x is currently:  14781
#  x is still less than 10, adding 1 to x
# x is currently:  14782
#  x is still less than 10, adding 1 to x
# x is currently:  14783
#  x is still less than 10, adding 1 to x
# x is currently:  14784
#  x is still less than 10, adding 1 to x
# x is currently:  14785
#  x is still less than 10, adding 1 to x
# x is currently:  14786
#  x is still less than 10, adding 1 to x
# x is currently:  14787
#  x is still less than 10, adding 1 to x
# x is currently:  14788
#  x is still less than 10, adding 1 to x
# x is currently:  14789
#  x is still less than 10, adding 1 to x
# x is currently:  14790
#  x is still less than 10, adding 1 to x
# x is currently:  14791
#  x is still less than 10, adding 1 to x
# x is currently:  14792
#  x is still less than 10, adding 1 to x
# x is currently:  14793
#  x is still less than 10, adding 1 to x
# x is currently:  14794
#  x is still less than 10, adding 1 to x
# x is currently:  14795
#  x is still less than 10, adding 1 to x
# x is currently:  14796
#  x is still less than 10, adding 1 to x
# x is currently:  14797
#  x is still less than 10, adding 1 to x
# x is currently:  14798
#  x is still less than 10, adding 1 to x
# x is currently:  14799
#  x is still less than 10, adding 1 to x
# x is currently:  14800
#  x is still less than 10, adding 1 to x
# x is currently:  14801
#  x is still less than 10, adding 1 to x
# x is currently:  14802
#  x is still less than 10, adding 1 to x
# x is currently:  14803
#  x is still less than 10, adding 1 to x
# x is currently:  14804
#  x is still less than 10, adding 1 to x
# x is currently:  14805
#  x is still less than 10, adding 1 to x
# x is currently:  14806
#  x is still less than 10, adding 1 to x
# x is currently:  14807
#  x is still less than 10, adding 1 to x
# x is currently:  14808
#  x is still less than 10, adding 1 to x
# x is currently:  14809
#  x is still less than 10, adding 1 to x
# x is currently:  14810
#  x is still less than 10, adding 1 to x
# x is currently:  14811
#  x is still less than 10, adding 1 to x
# x is currently:  14812
#  x is still less than 10, adding 1 to x
# x is currently:  14813
#  x is still less than 10, adding 1 to x
# x is currently:  14814
#  x is still less than 10, adding 1 to x
# x is currently:  14815
#  x is still less than 10, adding 1 to x
# x is currently:  14816
#  x is still less than 10, adding 1 to x
# x is currently:  14817
#  x is still less than 10, adding 1 to x
# x is currently:  14818
#  x is still less than 10, adding 1 to x
# x is currently:  14819
#  x is still less than 10, adding 1 to x
# x is currently:  14820
#  x is still less than 10, adding 1 to x
# x is currently:  14821
#  x is still less than 10, adding 1 to x
# x is currently:  14822
#  x is still less than 10, adding 1 to x
# x is currently:  14823
#  x is still less than 10, adding 1 to x
# x is currently:  14824
#  x is still less than 10, adding 1 to x
# x is currently:  14825
#  x is still less than 10, adding 1 to x
# x is currently:  14826
#  x is still less than 10, adding 1 to x
# x is currently:  14827
#  x is still less than 10, adding 1 to x
# x is currently:  14828
#  x is still less than 10, adding 1 to x
# x is currently:  14829
#  x is still less than 10, adding 1 to x
# x is currently:  14830
#  x is still less than 10, adding 1 to x
# x is currently:  14831
#  x is still less than 10, adding 1 to x
# x is currently:  14832
#  x is still less than 10, adding 1 to x
# x is currently:  14833
#  x is still less than 10, adding 1 to x
# x is currently:  14834
#  x is still less than 10, adding 1 to x
# x is currently:  14835
#  x is still less than 10, adding 1 to x
# x is currently:  14836
#  x is still less than 10, adding 1 to x
# x is currently:  14837
#  x is still less than 10, adding 1 to x
# x is currently:  14838
#  x is still less than 10, adding 1 to x
# x is currently:  14839
#  x is still less than 10, adding 1 to x
# x is currently:  14840
#  x is still less than 10, adding 1 to x
# x is currently:  14841
#  x is still less than 10, adding 1 to x
# x is currently:  14842
#  x is still less than 10, adding 1 to x
# x is currently:  14843
#  x is still less than 10, adding 1 to x
# x is currently:  14844
#  x is still less than 10, adding 1 to x
# x is currently:  14845
#  x is still less than 10, adding 1 to x
# x is currently:  14846
#  x is still less than 10, adding 1 to x
# x is currently:  14847
#  x is still less than 10, adding 1 to x
# x is currently:  14848
#  x is still less than 10, adding 1 to x
# x is currently:  14849
#  x is still less than 10, adding 1 to x
# x is currently:  14850
#  x is still less than 10, adding 1 to x
# x is currently:  14851
#  x is still less than 10, adding 1 to x
# x is currently:  14852
#  x is still less than 10, adding 1 to x
# x is currently:  14853
#  x is still less than 10, adding 1 to x
# x is currently:  14854
#  x is still less than 10, adding 1 to x
# x is currently:  14855
#  x is still less than 10, adding 1 to x
# x is currently:  14856
#  x is still less than 10, adding 1 to x
# x is currently:  14857
#  x is still less than 10, adding 1 to x
# x is currently:  14858
#  x is still less than 10, adding 1 to x
# x is currently:  14859
#  x is still less than 10, adding 1 to x
# x is currently:  14860
#  x is still less than 10, adding 1 to x
# x is currently:  14861
#  x is still less than 10, adding 1 to x
# x is currently:  14862
#  x is still less than 10, adding 1 to x
# x is currently:  14863
#  x is still less than 10, adding 1 to x
# x is currently:  14864
#  x is still less than 10, adding 1 to x
# x is currently:  14865
#  x is still less than 10, adding 1 to x
# x is currently:  14866
#  x is still less than 10, adding 1 to x
# x is currently:  14867
#  x is still less than 10, adding 1 to x
# x is currently:  14868
#  x is still less than 10, adding 1 to x
# x is currently:  14869
#  x is still less than 10, adding 1 to x
# x is currently:  14870
#  x is still less than 10, adding 1 to x
# x is currently:  14871
#  x is still less than 10, adding 1 to x
# x is currently:  14872
#  x is still less than 10, adding 1 to x
# x is currently:  14873
#  x is still less than 10, adding 1 to x
# x is currently:  14874
#  x is still less than 10, adding 1 to x
# x is currently:  14875
#  x is still less than 10, adding 1 to x
# x is currently:  14876
#  x is still less than 10, adding 1 to x
# x is currently:  14877
#  x is still less than 10, adding 1 to x
# x is currently:  14878
#  x is still less than 10, adding 1 to x
# x is currently:  14879
#  x is still less than 10, adding 1 to x
# x is currently:  14880
#  x is still less than 10, adding 1 to x
# x is currently:  14881
#  x is still less than 10, adding 1 to x
# x is currently:  14882
#  x is still less than 10, adding 1 to x
# x is currently:  14883
#  x is still less than 10, adding 1 to x
# x is currently:  14884
#  x is still less than 10, adding 1 to x
# x is currently:  14885
#  x is still less than 10, adding 1 to x
# x is currently:  14886
#  x is still less than 10, adding 1 to x
# x is currently:  14887
#  x is still less than 10, adding 1 to x
# x is currently:  14888
#  x is still less than 10, adding 1 to x
# x is currently:  14889
#  x is still less than 10, adding 1 to x
# x is currently:  14890
#  x is still less than 10, adding 1 to x
# x is currently:  14891
#  x is still less than 10, adding 1 to x
# x is currently:  14892
#  x is still less than 10, adding 1 to x
# x is currently:  14893
#  x is still less than 10, adding 1 to x
# x is currently:  14894
#  x is still less than 10, adding 1 to x
# x is currently:  14895
#  x is still less than 10, adding 1 to x
# x is currently:  14896
#  x is still less than 10, adding 1 to x
# x is currently:  14897
#  x is still less than 10, adding 1 to x
# x is currently:  14898
#  x is still less than 10, adding 1 to x
# x is currently:  14899
#  x is still less than 10, adding 1 to x
# x is currently:  14900
#  x is still less than 10, adding 1 to x
# x is currently:  14901
#  x is still less than 10, adding 1 to x
# x is currently:  14902
#  x is still less than 10, adding 1 to x
# x is currently:  14903
#  x is still less than 10, adding 1 to x
# x is currently:  14904
#  x is still less than 10, adding 1 to x
# x is currently:  14905
#  x is still less than 10, adding 1 to x
# x is currently:  14906
#  x is still less than 10, adding 1 to x
# x is currently:  14907
#  x is still less than 10, adding 1 to x
# x is currently:  14908
#  x is still less than 10, adding 1 to x
# x is currently:  14909
#  x is still less than 10, adding 1 to x
# x is currently:  14910
#  x is still less than 10, adding 1 to x
# x is currently:  14911
#  x is still less than 10, adding 1 to x
# x is currently:  14912
#  x is still less than 10, adding 1 to x
# x is currently:  14913
#  x is still less than 10, adding 1 to x
# x is currently:  14914
#  x is still less than 10, adding 1 to x
# x is currently:  14915
#  x is still less than 10, adding 1 to x
# x is currently:  14916
#  x is still less than 10, adding 1 to x
# x is currently:  14917
#  x is still less than 10, adding 1 to x
# x is currently:  14918
#  x is still less than 10, adding 1 to x
# x is currently:  14919
#  x is still less than 10, adding 1 to x
# x is currently:  14920
#  x is still less than 10, adding 1 to x
# x is currently:  14921
#  x is still less than 10, adding 1 to x
# x is currently:  14922
#  x is still less than 10, adding 1 to x
# x is currently:  14923
#  x is still less than 10, adding 1 to x
# x is currently:  14924
#  x is still less than 10, adding 1 to x
# x is currently:  14925
#  x is still less than 10, adding 1 to x
# x is currently:  14926
#  x is still less than 10, adding 1 to x
# x is currently:  14927
#  x is still less than 10, adding 1 to x
# x is currently:  14928
#  x is still less than 10, adding 1 to x
# x is currently:  14929
#  x is still less than 10, adding 1 to x
# x is currently:  14930
#  x is still less than 10, adding 1 to x
# x is currently:  14931
#  x is still less than 10, adding 1 to x
# x is currently:  14932
#  x is still less than 10, adding 1 to x
# x is currently:  14933
#  x is still less than 10, adding 1 to x
# x is currently:  14934
#  x is still less than 10, adding 1 to x
# x is currently:  14935
#  x is still less than 10, adding 1 to x
# x is currently:  14936
#  x is still less than 10, adding 1 to x
# x is currently:  14937
#  x is still less than 10, adding 1 to x
# x is currently:  14938
#  x is still less than 10, adding 1 to x
# x is currently:  14939
#  x is still less than 10, adding 1 to x
# x is currently:  14940
#  x is still less than 10, adding 1 to x
# x is currently:  14941
#  x is still less than 10, adding 1 to x
# x is currently:  14942
#  x is still less than 10, adding 1 to x
# x is currently:  14943
#  x is still less than 10, adding 1 to x
# x is currently:  14944
#  x is still less than 10, adding 1 to x
# x is currently:  14945
#  x is still less than 10, adding 1 to x
# x is currently:  14946
#  x is still less than 10, adding 1 to x
# x is currently:  14947
#  x is still less than 10, adding 1 to x
# x is currently:  14948
#  x is still less than 10, adding 1 to x
# x is currently:  14949
#  x is still less than 10, adding 1 to x
# x is currently:  14950
#  x is still less than 10, adding 1 to x
# x is currently:  14951
#  x is still less than 10, adding 1 to x
# x is currently:  14952
#  x is still less than 10, adding 1 to x
# x is currently:  14953
#  x is still less than 10, adding 1 to x
# x is currently:  14954
#  x is still less than 10, adding 1 to x
# x is currently:  14955
#  x is still less than 10, adding 1 to x
# x is currently:  14956
#  x is still less than 10, adding 1 to x
# x is currently:  14957
#  x is still less than 10, adding 1 to x
# x is currently:  14958
#  x is still less than 10, adding 1 to x
# x is currently:  14959
#  x is still less than 10, adding 1 to x
# x is currently:  14960
#  x is still less than 10, adding 1 to x
# x is currently:  14961
#  x is still less than 10, adding 1 to x
# x is currently:  14962
#  x is still less than 10, adding 1 to x
# x is currently:  14963
#  x is still less than 10, adding 1 to x
# x is currently:  14964
#  x is still less than 10, adding 1 to x
# x is currently:  14965
#  x is still less than 10, adding 1 to x
# x is currently:  14966
#  x is still less than 10, adding 1 to x
# x is currently:  14967
#  x is still less than 10, adding 1 to x
# x is currently:  14968
#  x is still less than 10, adding 1 to x
# x is currently:  14969
#  x is still less than 10, adding 1 to x
# x is currently:  14970
#  x is still less than 10, adding 1 to x
# x is currently:  14971
#  x is still less than 10, adding 1 to x
# x is currently:  14972
#  x is still less than 10, adding 1 to x
# x is currently:  14973
#  x is still less than 10, adding 1 to x
# x is currently:  14974
#  x is still less than 10, adding 1 to x
# x is currently:  14975
#  x is still less than 10, adding 1 to x
# x is currently:  14976
#  x is still less than 10, adding 1 to x
# x is currently:  14977
#  x is still less than 10, adding 1 to x
# x is currently:  14978
#  x is still less than 10, adding 1 to x
# x is currently:  14979
#  x is still less than 10, adding 1 to x
# x is currently:  14980
#  x is still less than 10, adding 1 to x
# x is currently:  14981
#  x is still less than 10, adding 1 to x
# x is currently:  14982
#  x is still less than 10, adding 1 to x
# x is currently:  14983
#  x is still less than 10, adding 1 to x
# x is currently:  14984
#  x is still less than 10, adding 1 to x
# x is currently:  14985
#  x is still less than 10, adding 1 to x
# x is currently:  14986
#  x is still less than 10, adding 1 to x
# -------------------------------------------------------------------------
# KeyboardInterrupt                       Traceback (most recent call last)
# <ipython-input-8-b341ca14c9b0> in <module>
#       3 while x > 10:
#       4     print('x is currently: ', x)
# ----> 5     print(' x is still less than 10, adding 1 to x')
#       6     x += 1
#
# ~/.pyenv/versions/3.7.2/envs/analysis/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~/.pyenv/versions/3.7.2/envs/analysis/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/.pyenv/versions/3.7.2/envs/analysis/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/.pyenv/versions/3.7.2/envs/analysis/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# Notice how many times the print statements occurred and how the <code>while</code> loop kept going until the True condition was met, which occurred once x==10. It's important to note that once this occurred the code stopped. Let's see how we could add an <code>else</code> statement:

# %%
x = 0

while x < 10:
    print('x is currently: ',x)
    print(' x is still less than 10, adding 1 to x')
    x+=1
    
else:
    print('All Done!')
# Out:
# x is currently:  0
#  x is still less than 10, adding 1 to x
# x is currently:  1
#  x is still less than 10, adding 1 to x
# x is currently:  2
#  x is still less than 10, adding 1 to x
# x is currently:  3
#  x is still less than 10, adding 1 to x
# x is currently:  4
#  x is still less than 10, adding 1 to x
# x is currently:  5
#  x is still less than 10, adding 1 to x
# x is currently:  6
#  x is still less than 10, adding 1 to x
# x is currently:  7
#  x is still less than 10, adding 1 to x
# x is currently:  8
#  x is still less than 10, adding 1 to x
# x is currently:  9
#  x is still less than 10, adding 1 to x
# All Done!

# %% [markdown]
# ## break, continue, pass

# %% [markdown]
# We can use <code>break</code>, <code>continue</code>, and <code>pass</code> statements in our loops to add additional functionality for various cases. The three statements are defined by:
#
#     break: Breaks out of the current closest enclosing loop.
#     continue: Goes to the top of the closest enclosing loop.
#     pass: Does nothing at all.
#
#
# Thinking about <code>break</code> and <code>continue</code> statements, the general format of the <code>while</code> loop looks like this:
#
#     while test:
#         code statement
#         if test:
#             break
#         if test:
#             continue
#     else:
#
# <code>break</code> and <code>continue</code> statements can appear anywhere inside the loop’s body, but we will usually put them further nested in conjunction with an <code>if</code> statement to perform an action based on some condition.
#
# Let's go ahead and look at some examples!

# %%
x = 0

while x < 10:
    print('x is currently: ',x)
    print(' x is still less than 10, adding 1 to x')
    x+=1
    if x==3:
        print('x==3')
    else:
        print('continuing...')
        continue
# Out:
# x is currently:  0
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  1
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  2
#  x is still less than 10, adding 1 to x
# x==3
# x is currently:  3
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  4
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  5
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  6
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  7
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  8
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  9
#  x is still less than 10, adding 1 to x
# continuing...

# %% [markdown]
# Note how we have a printed statement when x==3, and a continue being printed out as we continue through the outer while loop. Let's put in a break once x ==3 and see if the result makes sense:

# %%
x = 0

while x < 10:
    print('x is currently: ',x)
    print(' x is still less than 10, adding 1 to x')
    x+=1
    if x==3:
        print('Breaking because x==3')
        break
    else:
        print('continuing...')
        continue
# Out:
# x is currently:  0
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  1
#  x is still less than 10, adding 1 to x
# continuing...
# x is currently:  2
#  x is still less than 10, adding 1 to x
# Breaking because x==3

# %% [markdown]
# Note how the other <code>else</code> statement wasn't reached and continuing was never printed!
#
# After these brief but simple examples, you should feel comfortable using <code>while</code> statements in your code.
#
# **A word of caution however! It is possible to create an infinitely running loop with <code>while</code> statements. For example:**

# %%
# DO NOT RUN THIS CODE!!!! 
while True:
    print("I'm stuck in an infinite loop!")

# %% [markdown]
#  A quick note: If you *did* run the above cell, click on the Kernel menu above to restart the kernel

# %% [markdown]
# ---

# %% [markdown]
# # 2. Dictionaries

# %% [markdown]
# We've been learning about *sequences* in Python but now we're going to switch gears and learn about *mappings* in Python. If you're familiar with other languages you can think of these Dictionaries as hash tables.
#
# This section will serve as a brief introduction to dictionaries and consist of:
#
#     1.) Constructing a Dictionary
#     2.) Accessing objects from a dictionary
#     3.) Nesting Dictionaries
#     4.) Basic Dictionary Methods
#
# So what are mappings? Mappings are a collection of objects that are stored by a *key*, unlike a sequence that stored objects by their relative position. This is an important distinction, since mappings won't retain order since they have objects defined by a key.
#
# A Python dictionary consists of a key and then an associated value. That value can be almost any Python object.

# %% [markdown]
# ## Constructing a Dictionary

# %% [markdown]
# Let's see how we can construct dictionaries to get a better understanding of how they work!

# %%
# Make a dictionary with {} and : to signify a key and a value
my_dict = {'key1':'value1','key2':'value2'}

# %%
# Call values by their key
my_dict['key2']
# Out:
# 'value2'

# %% [markdown]
# Its important to note that dictionaries are very flexible in the data types they can hold. For example:

# %%
my_dict = {'key1':123,'key2':[12,23,33],'key3':['item0','item1','item2']}

# %%
# Let's call items from the dictionary
my_dict['key3']
# Out:
# ['item0', 'item1', 'item2']

# %%
# Can call an index on that value
my_dict['key3'][0]
# Out:
# 'item0'

# %%
# Can then even call methods on that value
my_dict['key3'][0].upper()
# Out:
# 'ITEM0'

# %% [markdown]
# We can affect the values of a key as well. For instance:

# %%
my_dict['key1']
# Out:
# 123

# %%
# Subtract 123 from the value
my_dict['key1'] = my_dict['key1'] - 123

# %%
#Check
my_dict['key1']
# Out:
# 0

# %% [markdown]
# A quick note, Python has a built-in method of doing a self subtraction or addition (or multiplication or division). We could have also used += or -= for the above statement. For example:

# %%
# Set the object equal to itself minus 123 
my_dict['key1'] -= 123
my_dict['key1']
# Out:
# -123

# %% [markdown]
# We can also create keys by assignment. For instance if we started off with an empty dictionary, we could continually add to it:

# %%
# Create a new dictionary
d = {}

# %%
# Create a new key through assignment
d['animal'] = 'Dog'

# %%
# Can do this with any object
d['answer'] = 42

# %%
#Show
d
# Out:
# {'animal': 'Dog', 'answer': 42}

# %% [markdown]
# ## Nesting with Dictionaries

# %% [markdown]
# Hopefully you're starting to see how powerful Python is with its flexibility of nesting objects and calling methods on them. Let's see a dictionary nested inside a dictionary:

# %%
# Dictionary nested inside a dictionary nested inside a dictionary
d = {'key1':{'nestkey':{'subnestkey':'value'}}}

# %% [markdown]
# Wow! That's a quite the inception of dictionaries! Let's see how we can grab that value:

# %%
# Keep calling the keys
d['key1']['nestkey']['subnestkey']
# Out:
# 'value'

# %% [markdown]
# ## A few Dictionary Methods

# %% [markdown]
# There are a few methods we can call on a dictionary. Let's get a quick introduction to a few of them:

# %%
# Create a typical dictionary
d = {'key1':1,'key2':2,'key3':3}

# %%
# Method to return a list of all keys 
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
# Method to grab all values
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
# Method to return tuples of all items  (we'll learn about tuples soon)
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3)])

# %% [markdown]
# Hopefully you now have a good basic understanding how to construct dictionaries. There's a lot more to go into here, but we will revisit dictionaries at later time. After this section all you need to know is how to create a dictionary and how to retrieve values from it.

# %% [markdown]
# ---

# %% [markdown]
# # 3. Tuples

# %% [markdown]
# In Python tuples are very similar to lists, however, unlike lists they are *immutable* meaning they can not be changed. You would use tuples to present things that shouldn't be changed, such as days of the week, or dates on a calendar.
#
# In this section, we will get a brief overview of the following:
#
#     1.) Constructing Tuples
#     2.) Basic Tuple Methods
#     3.) Immutability
#     4.) When to Use Tuples
#
# You'll have an intuition of how to use tuples based on what you've learned about lists. We can treat them very similarly with the major distinction being that tuples are immutable.

# %% [markdown]
# ## Constructing Tuples

# %% [markdown]
# The construction of a tuples use () with elements separated by commas. For example:

# %%
# Create a tuple
t = (1,2,3,6)

# %%
# Check len just like a list
len(t)
# Out:
# 4

# %%
# Can also mix object types
t = ('one',2)

# Show
t
# Out:
# ('one', 2)

# %%
# Use indexing just like we did in lists
t[0]
# Out:
# 'one'

# %%
# Slicing just like a list
t[-1]
# Out:
# 2

# %% [markdown]
# ## Basic Tuple Methods

# %% [markdown]
# Tuples have built-in methods, but not as many as lists do. Let's look at two of them:

# %%
# Use .index to enter a value and return the index
t.index('one')
# Out:
# 0

# %%
# Use .count to count the number of times a value appears
t.count('one')
# Out:
# 1

# %% [markdown]
# ## Immutability

# %% [markdown]
# It can't be stressed enough that tuples are immutable. To drive that point home:

# %%
t[0] = 'change'
# Out:
# ------------------------------------------------
# TypeError      Traceback (most recent call last)
# <ipython-input-68-9468ef3b159f> in <module>
# ----> 1 t[0] = 'change'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Because of this immutability, tuples can't grow. Once a tuple is made we can not add to it.

# %%
t.append('nope')
# Out:
# ------------------------------------------------
# AttributeError Traceback (most recent call last)
# <ipython-input-69-b75f5b09ac19> in <module>
# ----> 1 t.append('nope')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ## When to use Tuples

# %% [markdown]
# You may be wondering, "Why bother using tuples when they have fewer available methods?" To be honest, tuples are not used as often as lists in programming, but are used when immutability is necessary. If in your program you are passing around an object and need to make sure it does not get changed, then a tuple becomes your solution. It provides a convenient source of data integrity.
#
# You should now be able to create and use tuples in your programming as well as have an understanding of their immutability.
#
# Up next Sets and Booleans!!

# %% [markdown]
# ---

# %% [markdown]
# # 4. Set and Booleans

# %% [markdown]
# There are two other object types in Python that we should quickly cover: Sets and Booleans.

# %% [markdown]
# ## Sets

# %% [markdown]
# Sets are an unordered collection of *unique* elements. We can construct them by using the set() function. Let's go ahead and make a set to see how it works

# %%
x = set()

# %%
# We add to sets with the add() method
x.add(1)

# %%
#Show
x
# Out:
# {1}

# %% [markdown]
# Note the curly brackets. This does not indicate a dictionary! Although you can draw analogies as a set being a dictionary with only keys.
#
# We know that a set has only unique entries. So what happens when we try to add something that is already in a set?

# %%
# Add a different element
x.add(2)

# %%
#Show
x
# Out:
# {1, 2}

# %%
# Try to add the same element
x.add(1)

# %%
#Show
x
# Out:
# {1, 2}

# %% [markdown]
# Notice how it won't place another 1 there. That's because a set is only concerned with unique elements! We can cast a list with multiple repeat elements to a set to get the unique elements. For example:

# %%
# Create a list with repeats
list1 = [1,1,2,2,3,4,5,6,1,1]

# %%
# Cast as set to get unique values
set(list1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ## Booleans

# %%
# Set object to be a boolean
a = True

# %%
#Show
a
# Out:
# True

# %% [markdown]
# We can also use comparison operators to create booleans. We will go over all the comparison operators later on in the course.

# %%
# Output is boolean
1 > 2
# Out:
# False

# %% [markdown]
# We can use None as a placeholder for an object that we don't want to reassign yet:

# %%
# None placeholder
b = None

# %%
# Show
print(b)
# Out:
# None

# %% [markdown]
# Thats it! You should now have a basic understanding of Python objects and data structure types. Next, go ahead and do the assessment test!

# %% [markdown]
# ---
